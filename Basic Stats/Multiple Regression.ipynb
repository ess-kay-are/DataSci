# %%
#importing relevant packages for statistical analysis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn
seaborn.set()

# %%
#loading data for analysis
data = pd.read_csv('real_estate_price_size_year.csv')

# %%
#checking data
data
# Out:
#          price     size  year
# 0   234314.144   643.09  2015
# 1   228581.528   656.22  2009
# 2   281626.336   487.29  2018
# 3   401255.608  1504.75  2015
# 4   458674.256  1275.46  2009
# ..         ...      ...   ...
# 95  252460.400   549.80  2009
# 96  310522.592  1037.44  2009
# 97  383635.568  1504.75  2006
# 98  225145.248   648.29  2015
# 99  274922.856   705.29  2006
#
# [100 rows x 3 columns]

# %%
data.describe()
# Out:
#                price         size         year
# count     100.000000   100.000000   100.000000
# mean   292289.470160   853.024200  2012.600000
# std     77051.727525   297.941951     4.729021
# min    154282.128000   479.750000  2006.000000
# 25%    234280.148000   643.330000  2009.000000
# 50%    280590.716000   696.405000  2015.000000
# 75%    335723.696000  1029.322500  2018.000000
# max    500681.128000  1842.510000  2018.000000

# %%
#Defining IVs and DV variables for analysis
y = data['price']
x1 = data[['size', 'year']]

# %%
#Exploring the data visually -> DV price, IV size
plt.scatter(data['size'], y)
plt.xlabel('size', fontsize = 25)
plt.ylabel('price', fontsize = 25)
plt.show()

# %%
#Exploring the data visually -> DV price, IV size
plt.scatter(data['year'], y)
plt.xlabel('year', fontsize = 25)
plt.ylabel('price', fontsize = 25)
plt.show()

# %%
#Code for the analysis, ordinary least squares 
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()

# %%
#Print results
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.776
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     168.5
# Date:                Wed, 08 May 2024   Prob (F-statistic):           2.77e-32
# Time:                        15:47:44   Log-Likelihood:                -1191.7
# No. Observations:                 100   AIC:                             2389.
# Df Residuals:                      97   BIC:                             2397.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.772e+06   1.58e+06     -3.647      0.000   -8.91e+06   -2.63e+06
# ...
