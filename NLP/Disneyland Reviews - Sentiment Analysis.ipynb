# %% [markdown]
# # Context:
#
# This dataset contains::
# - Review ID
# - rating out of 5
# - comments by the rater.
# - Disneyland location (it's all California)
#
# The task is to create a sentiment analysis model that can classify the emotional sentiment of the review into positive and negative.
#
# Plan of attack:
# - Injest and process the data (remove missing values, etc.)
# - Split data into train/test (90 - 10)
# - Parse the data through an NLP model (tokenize, lemmatize, etc.)
# - Vectorize this data
# - Classify into positive and negative using appropriate classification models
# - Evaluate against testing data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
import sklearn
import spacy
import nltk

# %%
# data injestion
df = pd.read_csv('DisneylandReviews.csv')

# %% [markdown]
# # Explore the Data

# %%
#quick observation of data
df.head(5)
# Out:
#    Review_ID  Rating                                        Review_Text  \
# 0  670801367       5  This place has always been and forever will be...
# 1  670760708       5  A great day of simple fun and thrills. Bring c...
# 2  670565072       4  All and all a great day was had. The crowds ar...
# 3  670544335       5  Having been to the Florida location numerous t...
# 4  670472278       5  Had the 4 day pass, spent 3 at DL and one at C...
#
#                   Branch
# 0  Disneyland_California
# 1  Disneyland_California
# 2  Disneyland_California
# 3  Disneyland_California
# 4  Disneyland_California

# %%
df.dropna(how='any') #dropping any missing values row-wise
# Out:
#        Review_ID  Rating                                        Review_Text  \
# 0      670801367       5  This place has always been and forever will be...
# 1      670760708       5  A great day of simple fun and thrills. Bring c...
# 2      670565072       4  All and all a great day was had. The crowds ar...
# 3      670544335       5  Having been to the Florida location numerous t...
# 4      670472278       5  Had the 4 day pass, spent 3 at DL and one at C...
# ...          ...     ...                                                ...
# 19401    1563280       5  I have taken my music groups to Disneyland for...
# 19402    1540854       5  This is definitely the Happiest Place on Earth...
# 19403    1534364       1  never again...what a horrible experience, the ...
# 19404    1506324       5  We take a long weekend trip to California each...
# 19405    1398724       5  Disnyeland has to be the BEST place to take a ...
#
#                       Branch
# 0      Disneyland_California
# 1      Disneyland_California
# 2      Disneyland_California
# 3      Disneyland_California
# 4      Disneyland_California
# ...                      ...
# 19401  Disneyland_California
# 19402  Disneyland_California
# 19403  Disneyland_California
# 19404  Disneyland_California
# 19405  Disneyland_California
#
# [19406 rows x 4 columns]

# %%
df['Rating'].value_counts().sort_index().plot(kind='bar', title='Number of Review by Ratings',
                                             figsize=(10,5))
# Out:
# <Axes: title={'center': 'Number of Review by Ratings'}, xlabel='Rating'>

# %% [markdown]
# # Initial NLTK
#
# Doing some basic work with the NLTK on a random review to get the feel of it.

# %%
example = df['Review_Text'][420]
print(example)
# Out:
# This park was hours of walking, but had a whole day of things to do! We enjoyed all of it. The only wish I wouldn't have done...wait 45 minutes for Peter Pan...I should have done the Winnie the Pooh ride 2x instead! Clean, Fun, and a full fun day experience!!

# %%
token_eg = nltk.word_tokenize(example)

# %%
tagged_eg = nltk.pos_tag(token_eg)
print(tagged_eg)
# Out:
# [('This', 'DT'), ('park', 'NN'), ('was', 'VBD'), ('hours', 'NNS'), ('of', 'IN'), ('walking', 'NN'), (',', ','), ('but', 'CC'), ('had', 'VBD'), ('a', 'DT'), ('whole', 'JJ'), ('day', 'NN'), ('of', 'IN'), ('things', 'NNS'), ('to', 'TO'), ('do', 'VB'), ('!', '.'), ('We', 'PRP'), ('enjoyed', 'VBD'), ('all', 'DT'), ('of', 'IN'), ('it', 'PRP'), ('.', '.'), ('The', 'DT'), ('only', 'JJ'), ('wish', 'NN'), ('I', 'PRP'), ('would', 'MD'), ("n't", 'RB'), ('have', 'VB'), ('done', 'VBN'), ('...', ':'), ('wait', 'VBP'), ('45', 'CD'), ('minutes', 'NNS'), ('for', 'IN'), ('Peter', 'NNP'), ('Pan', 'NNP'), ('...', ':'), ('I', 'PRP'), ('should', 'MD'), ('have', 'VB'), ('done', 'VBN'), ('the', 'DT'), ('Winnie', 'NNP'), ('the', 'DT'), ('Pooh', 'NNP'), ('ride', 'VBP'), ('2x', 'CD'), ('instead', 'RB'), ('!', '.'), ('Clean', 'NNP'), (',', ','), ('Fun', 'NNP'), (',', ','), ('and', 'CC'), ('a', 'DT'), ('full', 'JJ'), ('fun', 'NN'), ('day', 'NN'), ('experience', 'NN'), ('!', '.'), ('!', '.')]

# %%
entities_eg = nltk.chunk.ne_chunk(tagged_eg)
entities_eg.pprint()
# Out:
# (S
#   This/DT
#   park/NN
#   was/VBD
#   hours/NNS
#   of/IN
#   walking/NN
#   ,/,
#   but/CC
#   had/VBD
#   a/DT
#   whole/JJ
#   day/NN
#   of/IN
#   things/NNS
#   to/TO
#   do/VB
#   !/.
#   We/PRP
#   enjoyed/VBD
#   all/DT
#   of/IN
#   it/PRP
#   ./.
#   The/DT
#   only/JJ
#   wish/NN
#   I/PRP
#   would/MD
#   n't/RB
#   have/VB
#   done/VBN
#   .../:
#   wait/VBP
#   45/CD
#   minutes/NNS
#   for/IN
#   (PERSON Peter/NNP Pan/NNP)
#   .../:
#   I/PRP
#   should/MD
#   have/VB
#   done/VBN
#   the/DT
#   Winnie/NNP
#   the/DT
#   Pooh/NNP
#   ride/VBP
#   2x/CD
#   instead/RB
#   !/.
#   (PERSON Clean/NNP)
#   ,/,
#   (PERSON Fun/NNP)
#   ,/,
#   and/CC
#   a/DT
#   full/JJ
#   fun/NN
#   day/NN
#   experience/NN
#   !/.
#   !/.)

# %% [markdown]
# # Step 1. Valence Aware Dictionary and sEntiment Reasoner (VADER)
#
# Using a bag of words approach to classify positive and negative sentiment.
#
# This model will remove stopwords (i.e., filler words) as part of its process.

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

# %%
sia = SentimentIntensityAnalyzer()

# %%
#poliarity score on the dataset
results = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Review_Text']
    myid = row['Review_ID']
    results[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/19406 [00:00<?, ?it/s]

# %%
vaders = pd.DataFrame.from_dict(results, orient='index')
vaders = pd.DataFrame(results).T
vaders = vaders.reset_index().rename(columns={'index':'Review_ID'})
vaders = vaders.merge(df,how='left',on='Review_ID')
# merging the vaders dataset with the df original dataset

# %%
vaders.head(3) #checking the merger was successful
# Out:
#    Review_ID    neg    neu    pos  compound  Rating  \
# 0  670801367  0.000  0.754  0.246    0.9008       5
# 1  670760708  0.000  0.741  0.259    0.9595       5
# 2  670565072  0.087  0.729  0.184    0.7319       4
#
#                                          Review_Text                 Branch
# 0  This place has always been and forever will be...  Disneyland_California
# 1  A great day of simple fun and thrills. Bring c...  Disneyland_California
# 2  All and all a great day was had. The crowds ar...  Disneyland_California

# %% [markdown]
# ### Plotting VADER Results

# %%
ax = sns.barplot(data=vaders, x='Rating', y='compound')
ax.set_title('Compound Score by Rating')
plt.show()

# %%
#make subplots side by side for comparison, by pos/neu/neg scores by Vader
fig, axs = plt.subplots(1, 3, figsize=(15,5))
sns.barplot(data=vaders, x='Rating', y='pos', ax = axs[0])
sns.barplot(data=vaders, x='Rating', y='neu', ax = axs[1])
sns.barplot(data=vaders, x='Rating', y='neg', ax = axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %% [markdown]
# These results are pretty much what we'd expect. Firstly, the positive VADER scores are most represented for the higher ratings out of 5. The negative VADER scores are most represented for the lower ratings. For neutral, it seems fairly even, except that 4 and 5 star ratings tend to have less neutrally-scored sentiment by VADERS. For neutral, this is neither here nor there, as neutral words aren't the most important. The most important insight we have here, is that there seems to be a strong correlation between positive/negative sentiment, and the ratings made by customers.
#
# Same can be said for the compound scores. Negative compound sentiment scores are most prevalent at the lower ratings, the opposite being true for the higher ratings.
#
# Overall, this confirms an initial inuititive hypothesis that ratings given by customers will have a strong correlation to the sentiment expressed in their written review.

# %% [markdown]
# # Robustly Optimized BERT Approach (RoBERTa) Pretrained Model
#
# This is a pre-trained deep learning model.
#
# This model uses transformers - which helps detect valance from the context of words. I.e., having certain words positioned in a sentence next to others, in certain orders, etc., that give it extra meaning. VADERS simply looked at each individual token (minus stopwords), categorised it as positive/neutral/negative, adds them up, then spits out a score. RoBERTa, on the other hand will look at tokens and their relative positioning within their sentence to give a more nuanced sentiment score.

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax
import torch

# %%
#enabling CUDA to speed up the processing speeds - this checks to ensure there's a device capable
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
#loading the relevant models

# %%
model.to(device)
device
#enables CUDA for the model
# Out:
# device(type='cuda')

# %% [markdown]
# ### Example and Brief Comparison

# %%
print(example) #a relatively positive example of text, to show how the two models work differently
# Out:
# This park was hours of walking, but had a whole day of things to do! We enjoyed all of it. The only wish I wouldn't have done...wait 45 minutes for Peter Pan...I should have done the Winnie the Pooh ride 2x instead! Clean, Fun, and a full fun day experience!!

# %%
encoded = tokenizer(example, return_tensors='pt')
encoded = {key: value.to(device) for key, value in encoded.items()} #example to show what the model is doing
with torch.no_grad():
    eg_output = model(**encoded)
scores = eg_output.logits[0].detach().cpu().numpy()
scores = softmax(scores)
scores

#scores from left to right are, negative, neutral, positive. Similar to the VADERS output but using the Roberta model.
# Out:
# array([0.0084276 , 0.03174039, 0.95983195], dtype=float32)

# %%
sia.polarity_scores(example) #this is using the VADERS model.
# Out:
# {'neg': 0.0, 'neu': 0.66, 'pos': 0.34, 'compound': 0.9739}

# %% [markdown]
# The results on the example text from earlier show that the the neutral score has significantly decreased, while the positive score has significantly incerased moving from VADERS to Roberta.
#
# A big reason for this is the increased contextual sensitivity. By looking at how the words relate within their sentences, a more nuanced score can be extracted.
#
# However, interestingly, the compound score of VADERS is similar to the overall positive score of the Roberta model. This is because the VADERS model gives all its neutral score to the higher of the pos/neg, which is a very rough heuristic.

# %% [markdown]
# ## Analysis of Review Text
#
# Analysing review text with the RoBERTa model.

# %%
def polarity_scores_roberta(text):
    encoded = tokenizer(text, return_tensors='pt', max_length=512, truncation=True)
    encoded = {key: value.to(device) for key, value in encoded.items()}
    with torch.no_grad():
        eg_output = model(**encoded)
    logits = eg_output.logits[0].detach().cpu().numpy()
    scores = softmax(logits)
    scores_dict = {
        'roberta_neg': scores[0],
        'roberta_neu': scores[1],
        'roberta_pos': scores[2]
    }
    return scores_dict

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Review_Text']
    myid = row['Review_ID']
    vader_result = sia.polarity_scores(text)
    vader_result_rename = {f"vader_{key}": value for key, value in vader_result.items()}
    roberta_result = polarity_scores_roberta(text)
    both = {**vader_result_rename, **roberta_result}
    res[myid] = both
# Out:
#   0%|          | 0/19406 [00:00<?, ?it/s]

# %%
res #see the results and ensure all the lines of the function have worked properly
# Out:
# {670801367: {'vader_neg': 0.0,
#   'vader_neu': 0.754,
#   'vader_pos': 0.246,
#   'vader_compound': 0.9008,
#   'roberta_neg': 0.001560148,
#   'roberta_neu': 0.009007211,
#   'roberta_pos': 0.98943263},
#  670760708: {'vader_neg': 0.0,
#   'vader_neu': 0.741,
#   'vader_pos': 0.259,
#   'vader_compound': 0.9595,
#   'roberta_neg': 0.0016031032,
#   'roberta_neu': 0.010467633,
#   'roberta_pos': 0.9879292},
#  670565072: {'vader_neg': 0.087,
#   'vader_neu': 0.729,
#   'vader_pos': 0.184,
#   'vader_compound': 0.7319,
#   'roberta_neg': 0.009501186,
#   'roberta_neu': 0.053587765,
#   'roberta_pos': 0.93691105},
#  670544335: {'vader_neg': 0.072,
#   'vader_neu': 0.78,
#   'vader_pos': 0.148,
#   'vader_compound': 0.9458,
#   'roberta_neg': 0.0094135925,
#   'roberta_neu': 0.043673318,
#   'roberta_pos': 0.94691306},
#  670472278: {'vader_neg': 0.075,
#   'vader_neu': 0.821,
#   'vader_pos': 0.104,
#   'vader_compound': 0.0572,
#   'roberta_neg': 0.0040909634,
#   'roberta_neu': 0.039689627,
#   'roberta_pos': 0.95621943},
#  670382191: {'vader_neg': 0.078,
#   'vader_neu': 0.534,
#   'vader_pos': 0.388,
#   'vader_compound': 0.8275,
#   'roberta_neg': 0.0051562996,
#   'roberta_neu': 0.022008542,
#   'roberta_pos': 0.9728352},
#  670303452: {'vader_neg': 0.087,
#   'vader_neu': 0.712,
#   'vader_pos': 0.201,
#   'vader_compound': 0.9636,
#   'roberta_neg': 0.0052137817,
#   'roberta_neu': 0.026018862,
#   'roberta_pos': 0.96876734},
#  670215409: {'vader_neg': 0.077,
#   'vader_neu': 0.76,
#   'vader_pos': 0.163,
#   'vader_compound': 0.8504,
#   'roberta_neg': 0.25043944,
#   'roberta_neu': 0.37300363,
#   'roberta_pos': 0.376557},
#  670204404: {'vader_neg': 0.015,
#   'vader_neu': 0.806,
#   'vader_pos': 0.179,
#   'vader_compound': 0.9543,
#   'roberta_neg': 0.008521825,
#   'roberta_neu': 0.06381364,
#   'roberta_pos': 0.9276646},
#  670164415: {'vader_neg': 0.017,
#   'vader_neu': 0.724,
#   'vader_pos': 0.258,
#   'vader_compound': 0.9909,
#   'roberta_neg': 0.004353836,
#   'roberta_neu': 0.023470104,
#   'roberta_pos': 0.9721761},
#  669945103: {'vader_neg': 0.025,
#   'vader_neu': 0.884,
#   'vader_pos': 0.091,
#   'vader_compound': 0.7759,
#   'roberta_neg': 0.020416943,
#   'roberta_neu': 0.15195206,
#   'roberta_pos': 0.827631},
#  669762024: {'vader_neg': 0.015,
#   'vader_neu': 0.866,
#   'vader_pos': 0.119,
#   'vader_compound': 0.987,
#   'roberta_neg': 0.0091850385,
#   'roberta_neu': 0.15568794,
#   'roberta_pos': 0.83512706},
#  669706763: {'vader_neg': 0.046,
#   'vader_neu': 0.786,
#   'vader_pos': 0.167,
#   'vader_compound': 0.9987,
#   'roberta_neg': 0.27795458,
#   'roberta_neu': 0.39495027,
#   'roberta_pos': 0.32709515},
#  669660324: {'vader_neg': 0.119,
#   'vader_neu': 0.76,
#   'vader_pos': 0.121,
#   'vader_compound': 0.4855,
#   'roberta_neg': 0.64828664,
#   'roberta_neu': 0.26531902,
#   'roberta_pos': 0.086394325},
#  669624661: {'vader_neg': 0.066,
#   'vader_neu': 0.726,
#   'vader_pos': 0.208,
#   'vader_compound': 0.6486,
#   'roberta_neg': 0.0046600993,
#   'roberta_neu': 0.017315775,
#   'roberta_pos': 0.9780241},
#  669535760: {'vader_neg': 0.057,
#   'vader_neu': 0.677,
#   'vader_pos': 0.265,
#   'vader_compound': 0.8395,
#   'roberta_neg': 0.002432665,
#   'roberta_neu': 0.02448405,
#   'roberta_pos': 0.97308326},
#  669505006: {'vader_neg': 0.096,
#   'vader_neu': 0.836,
#   'vader_pos': 0.068,
#   'vader_compound': -0.457,
#   'roberta_neg': 0.69671303,
#   'roberta_neu': 0.2350113,
#   'roberta_pos': 0.0682757},
#  668986571: {'vader_neg': 0.0,
#   'vader_neu': 0.768,
#   'vader_pos': 0.232,
#   'vader_compound': 0.9382,
#   'roberta_neg': 0.0019124334,
#   'roberta_neu': 0.017289413,
#   'roberta_pos': 0.9807982},
#  668793602: {'vader_neg': 0.026,
#   'vader_neu': 0.883,
#   'vader_pos': 0.091,
#   'vader_compound': 0.9722,
#   'roberta_neg': 0.04983765,
#   'roberta_neu': 0.27052367,
#   'roberta_pos': 0.6796387},
#  668772767: {'vader_neg': 0.027,
#   'vader_neu': 0.757,
#   'vader_pos': 0.217,
#   'vader_compound': 0.9238,
#   'roberta_neg': 0.0023646948,
#   'roberta_neu': 0.013596054,
#   'roberta_pos': 0.98403925},
#  668759002: {'vader_neg': 0.0,
#   'vader_neu': 0.782,
#   'vader_pos': 0.218,
#   'vader_compound': 0.8778,
#   'roberta_neg': 0.0044400026,
#   'roberta_neu': 0.042005844,
#   'roberta_pos': 0.9535541},
#  668734266: {'vader_neg': 0.0,
#   'vader_neu': 0.866,
#   'vader_pos': 0.134,
#   'vader_compound': 0.9468,
#   'roberta_neg': 0.0038336415,
#   'roberta_neu': 0.033514574,
#   'roberta_pos': 0.9626517},
#  668730191: {'vader_neg': 0.106,
#   'vader_neu': 0.794,
#   'vader_pos': 0.099,
#   'vader_compound': -0.2291,
#   'roberta_neg': 0.7471841,
#   'roberta_neu': 0.20475239,
#   'roberta_pos': 0.048063517},
#  668642940: {'vader_neg': 0.0,
#   'vader_neu': 0.834,
#   'vader_pos': 0.166,
#   'vader_compound': 0.5255,
#   'roberta_neg': 0.0010092403,
#   'roberta_neu': 0.013620452,
#   'roberta_pos': 0.9853703},
#  668497633: {'vader_neg': 0.0,
#   'vader_neu': 0.726,
#   'vader_pos': 0.274,
#   'vader_compound': 0.9694,
#   'roberta_neg': 0.0019750872,
#   'roberta_neu': 0.0074505615,
#   'roberta_pos': 0.9905744},
#  668473655: {'vader_neg': 0.07,
#   'vader_neu': 0.754,
#   'vader_pos': 0.176,
#   'vader_compound': 0.8514,
#   'roberta_neg': 0.0056623737,
#   'roberta_neu': 0.036114026,
#   'roberta_pos': 0.95822364},
#  668205119: {'vader_neg': 0.14,
#   'vader_neu': 0.468,
#   'vader_pos': 0.392,
#   'vader_compound': 0.7621,
#   'roberta_neg': 0.029565306,
#   'roberta_neu': 0.20737532,
#   'roberta_pos': 0.7630594},
#  668183645: {'vader_neg': 0.0,
#   'vader_neu': 0.746,
#   'vader_pos': 0.254,
#   'vader_compound': 0.9735,
#   'roberta_neg': 0.0014770934,
#   'roberta_neu': 0.0075927377,
#   'roberta_pos': 0.99093014},
#  668118511: {'vader_neg': 0.029,
#   'vader_neu': 0.76,
#   'vader_pos': 0.211,
#   'vader_compound': 0.9827,
#   'roberta_neg': 0.013200327,
#   'roberta_neu': 0.08057486,
#   'roberta_pos': 0.90622485},
#  668062117: {'vader_neg': 0.0,
#   'vader_neu': 0.557,
#   'vader_pos': 0.443,
#   'vader_compound': 0.8982,
#   'roberta_neg': 0.001638187,
#   'roberta_neu': 0.010827755,
#   'roberta_pos': 0.98753405},
#  667955757: {'vader_neg': 0.059,
#   'vader_neu': 0.848,
#   'vader_pos': 0.093,
#   'vader_compound': 0.8401,
#   'roberta_neg': 0.48135167,
#   'roberta_neu': 0.35734704,
#   'roberta_pos': 0.16130127},
#  667949122: {'vader_neg': 0.026,
#   'vader_neu': 0.8,
#   'vader_pos': 0.174,
#   'vader_compound': 0.9312,
#   'roberta_neg': 0.0023462202,
#   'roberta_neu': 0.010661791,
#   'roberta_pos': 0.986992},
#  667858131: {'vader_neg': 0.038,
#   'vader_neu': 0.684,
#   'vader_pos': 0.278,
#   'vader_compound': 0.9413,
#   'roberta_neg': 0.0019253598,
#   'roberta_neu': 0.008471309,
#   'roberta_pos': 0.98960334},
#  667857090: {'vader_neg': 0.0,
#   'vader_neu': 0.749,
#   'vader_pos': 0.251,
#   'vader_compound': 0.8126,
#   'roberta_neg': 0.01021045,
#   'roberta_neu': 0.0813657,
#   'roberta_pos': 0.9084238},
#  667491422: {'vader_neg': 0.014,
#   'vader_neu': 0.785,
#   'vader_pos': 0.201,
#   'vader_compound': 0.9918,
#   'roberta_neg': 0.0027625351,
#   'roberta_neu': 0.0213091,
#   'roberta_pos': 0.97592837},
#  667490475: {'vader_neg': 0.059,
#   'vader_neu': 0.769,
#   'vader_pos': 0.171,
#   'vader_compound': 0.9857,
#   'roberta_neg': 0.0098402575,
#   'roberta_neu': 0.07699917,
#   'roberta_pos': 0.91316056},
#  667376527: {'vader_neg': 0.059,
#   'vader_neu': 0.654,
#   'vader_pos': 0.288,
#   'vader_compound': 0.8593,
#   'roberta_neg': 0.007387764,
#   'roberta_neu': 0.036271702,
#   'roberta_pos': 0.95634055},
#  667084672: {'vader_neg': 0.0,
#   'vader_neu': 0.807,
#   'vader_pos': 0.193,
#   'vader_compound': 0.8555,
#   'roberta_neg': 0.0051443637,
#   'roberta_neu': 0.11533595,
#   'roberta_pos': 0.8795197},
#  667081128: {'vader_neg': 0.0,
#   'vader_neu': 0.805,
#   'vader_pos': 0.195,
#   'vader_compound': 0.9229,
#   'roberta_neg': 0.0016601341,
#   'roberta_neu': 0.005400636,
#   'roberta_pos': 0.99293923},
#  666821668: {'vader_neg': 0.023,
#   'vader_neu': 0.827,
#   'vader_pos': 0.149,
#   'vader_compound': 0.944,
#   'roberta_neg': 0.00398612,
#   'roberta_neu': 0.02770007,
#   'roberta_pos': 0.9683138},
#  666819537: {'vader_neg': 0.0,
#   'vader_neu': 0.917,
#   'vader_pos': 0.083,
#   'vader_compound': 0.471,
#   'roberta_neg': 0.0011822564,
#   'roberta_neu': 0.011972797,
#   'roberta_pos': 0.9868449},
#  666801789: {'vader_neg': 0.076,
#   'vader_neu': 0.706,
#   'vader_pos': 0.217,
#   'vader_compound': 0.9069,
#   'roberta_neg': 0.009031535,
#   'roberta_neu': 0.027210943,
#   'roberta_pos': 0.9637575},
#  666796062: {'vader_neg': 0.075,
#   'vader_neu': 0.439,
#   'vader_pos': 0.486,
#   'vader_compound': 0.9882,
#   'roberta_neg': 0.00217769,
#   'roberta_neu': 0.0056681037,
#   'roberta_pos': 0.9921542},
#  666790455: {'vader_neg': 0.0,
#   'vader_neu': 0.731,
#   'vader_pos': 0.269,
#   'vader_compound': 0.811,
#   'roberta_neg': 0.017071674,
#   'roberta_neu': 0.105395384,
#   'roberta_pos': 0.87753296},
#  666722948: {'vader_neg': 0.091,
#   'vader_neu': 0.644,
#   'vader_pos': 0.265,
#   'vader_compound': 0.6506,
#   'roberta_neg': 0.0027921114,
#   'roberta_neu': 0.005983038,
#   'roberta_pos': 0.9912248},
#  666665841: {'vader_neg': 0.023,
#   'vader_neu': 0.627,
#   'vader_pos': 0.35,
#   'vader_compound': 0.9924,
#   'roberta_neg': 0.0013428023,
#   'roberta_neu': 0.0070924982,
#   'roberta_pos': 0.99156475},
#  666536505: {'vader_neg': 0.0,
#   'vader_neu': 0.73,
#   'vader_pos': 0.27,
#   'vader_compound': 0.9483,
#   'roberta_neg': 0.0020691548,
#   'roberta_neu': 0.0072961967,
#   'roberta_pos': 0.9906346},
#  666534210: {'vader_neg': 0.026,
#   'vader_neu': 0.72,
#   'vader_pos': 0.254,
#   'vader_compound': 0.9623,
#   'roberta_neg': 0.002046634,
#   'roberta_neu': 0.011554708,
#   'roberta_pos': 0.98639864},
#  666498247: {'vader_neg': 0.068,
#   'vader_neu': 0.807,
#   'vader_pos': 0.125,
#   'vader_compound': 0.803,
#   'roberta_neg': 0.024956923,
#   'roberta_neu': 0.14794303,
#   'roberta_pos': 0.82710004},
#  666486707: {'vader_neg': 0.033,
#   'vader_neu': 0.703,
#   'vader_pos': 0.265,
#   'vader_compound': 0.9723,
#   'roberta_neg': 0.0029713153,
#   'roberta_neu': 0.012793382,
#   'roberta_pos': 0.9842353},
#  666370471: {'vader_neg': 0.0,
#   'vader_neu': 0.748,
#   'vader_pos': 0.252,
#   'vader_compound': 0.9508,
#   'roberta_neg': 0.0010377206,
#   'roberta_neu': 0.011005762,
#   'roberta_pos': 0.98795646},
#  666230995: {'vader_neg': 0.0,
#   'vader_neu': 0.74,
#   'vader_pos': 0.26,
#   'vader_compound': 0.8313,
#   'roberta_neg': 0.0018898575,
#   'roberta_neu': 0.013845903,
#   'roberta_pos': 0.9842643},
#  666230333: {'vader_neg': 0.0,
#   'vader_neu': 0.634,
#   'vader_pos': 0.366,
#   'vader_compound': 0.886,
#   'roberta_neg': 0.0022516034,
#   'roberta_neu': 0.014885758,
#   'roberta_pos': 0.98286265},
#  665989449: {'vader_neg': 0.0,
#   'vader_neu': 0.893,
#   'vader_pos': 0.107,
#   'vader_compound': 0.34,
#   'roberta_neg': 0.0015143275,
#   'roberta_neu': 0.0055656363,
#   'roberta_pos': 0.99292},
#  665976788: {'vader_neg': 0.0,
#   'vader_neu': 0.669,
#   'vader_pos': 0.331,
#   'vader_compound': 0.9243,
#   'roberta_neg': 0.0012629357,
#   'roberta_neu': 0.006134819,
#   'roberta_pos': 0.9926023},
#  665938110: {'vader_neg': 0.0,
#   'vader_neu': 0.66,
#   'vader_pos': 0.34,
#   'vader_compound': 0.9161,
#   'roberta_neg': 0.0017665079,
#   'roberta_neu': 0.012898972,
#   'roberta_pos': 0.9853345},
#  665929975: {'vader_neg': 0.032,
#   'vader_neu': 0.799,
#   'vader_pos': 0.17,
#   'vader_compound': 0.9863,
#   'roberta_neg': 0.013918428,
#   'roberta_neu': 0.054104995,
#   'roberta_pos': 0.93197656},
#  665898455: {'vader_neg': 0.144,
#   'vader_neu': 0.755,
#   'vader_pos': 0.1,
#   'vader_compound': -0.7293,
#   'roberta_neg': 0.26659742,
#   'roberta_neu': 0.33362535,
#   'roberta_pos': 0.39977726},
#  665826615: {'vader_neg': 0.021,
#   'vader_neu': 0.814,
#   'vader_pos': 0.165,
#   'vader_compound': 0.9887,
#   'roberta_neg': 0.0017923957,
#   'roberta_neu': 0.014303969,
#   'roberta_pos': 0.98390365},
#  665630903: {'vader_neg': 0.028,
#   'vader_neu': 0.747,
#   'vader_pos': 0.225,
#   'vader_compound': 0.9323,
#   'roberta_neg': 0.0013006626,
#   'roberta_neu': 0.009449248,
#   'roberta_pos': 0.98925006},
#  665504287: {'vader_neg': 0.092,
#   'vader_neu': 0.524,
#   'vader_pos': 0.384,
#   'vader_compound': 0.7717,
#   'roberta_neg': 0.017453713,
#   'roberta_neu': 0.09340929,
#   'roberta_pos': 0.88913697},
#  665488609: {'vader_neg': 0.022,
#   'vader_neu': 0.691,
#   'vader_pos': 0.287,
#   'vader_compound': 0.9739,
#   'roberta_neg': 0.002080173,
#   'roberta_neu': 0.008339596,
#   'roberta_pos': 0.9895802},
#  665102974: {'vader_neg': 0.0,
#   'vader_neu': 0.749,
#   'vader_pos': 0.251,
#   'vader_compound': 0.7717,
#   'roberta_neg': 0.0016779347,
#   'roberta_neu': 0.014577872,
#   'roberta_pos': 0.9837442},
#  664908302: {'vader_neg': 0.0,
#   'vader_neu': 0.902,
#   'vader_pos': 0.098,
#   'vader_compound': 0.8047,
#   'roberta_neg': 0.0028153223,
#   'roberta_neu': 0.086086206,
#   'roberta_pos': 0.91109854},
#  664832055: {'vader_neg': 0.053,
#   'vader_neu': 0.804,
#   'vader_pos': 0.143,
#   'vader_compound': 0.7997,
#   'roberta_neg': 0.19057268,
#   'roberta_neu': 0.36052212,
#   'roberta_pos': 0.44890514},
#  664795557: {'vader_neg': 0.0,
#   'vader_neu': 0.886,
#   'vader_pos': 0.114,
#   'vader_compound': 0.6486,
#   'roberta_neg': 0.0017955219,
#   'roberta_neu': 0.024869412,
#   'roberta_pos': 0.973335},
#  664633147: {'vader_neg': 0.0,
#   'vader_neu': 0.67,
#   'vader_pos': 0.33,
#   'vader_compound': 0.9828,
#   'roberta_neg': 0.002087467,
#   'roberta_neu': 0.007054886,
#   'roberta_pos': 0.99085766},
#  664615049: {'vader_neg': 0.145,
#   'vader_neu': 0.79,
#   'vader_pos': 0.066,
#   'vader_compound': -0.8831,
#   'roberta_neg': 0.95742726,
#   'roberta_neu': 0.036079243,
#   'roberta_pos': 0.0064935735},
#  664609925: {'vader_neg': 0.037,
#   'vader_neu': 0.682,
#   'vader_pos': 0.281,
#   'vader_compound': 0.9403,
#   'roberta_neg': 0.001454169,
#   'roberta_neu': 0.009803191,
#   'roberta_pos': 0.9887426},
#  664518632: {'vader_neg': 0.0,
#   'vader_neu': 0.72,
#   'vader_pos': 0.28,
#   'vader_compound': 0.9637,
#   'roberta_neg': 0.0013134415,
#   'roberta_neu': 0.006877657,
#   'roberta_pos': 0.99180895},
#  664091577: {'vader_neg': 0.0,
#   'vader_neu': 1.0,
#   'vader_pos': 0.0,
#   'vader_compound': 0.0,
#   'roberta_neg': 0.002073558,
#   'roberta_neu': 0.025395695,
#   'roberta_pos': 0.9725308},
#  663986221: {'vader_neg': 0.02,
#   'vader_neu': 0.936,
#   'vader_pos': 0.044,
#   'vader_compound': 0.8195,
#   'roberta_neg': 0.44777495,
#   'roberta_neu': 0.40609616,
#   'roberta_pos': 0.14612891},
#  663878298: {'vader_neg': 0.037,
#   'vader_neu': 0.717,
#   'vader_pos': 0.247,
#   'vader_compound': 0.9974,
#   'roberta_neg': 0.047473364,
#   'roberta_neu': 0.1721562,
#   'roberta_pos': 0.7803704},
#  663866608: {'vader_neg': 0.0,
#   'vader_neu': 0.375,
#   'vader_pos': 0.625,
#   'vader_compound': 0.9731,
#   'roberta_neg': 0.0013038393,
#   'roberta_neu': 0.009297264,
#   'roberta_pos': 0.98939896},
#  663791913: {'vader_neg': 0.075,
#   'vader_neu': 0.883,
#   'vader_pos': 0.042,
#   'vader_compound': -0.6847,
#   'roberta_neg': 0.6448077,
#   'roberta_neu': 0.29491597,
#   'roberta_pos': 0.060276322},
#  663317002: {'vader_neg': 0.0,
#   'vader_neu': 0.788,
#   'vader_pos': 0.212,
#   'vader_compound': 0.9118,
#   'roberta_neg': 0.0015693749,
#   'roberta_neu': 0.0065673226,
#   'roberta_pos': 0.99186325},
#  663228213: {'vader_neg': 0.089,
#   'vader_neu': 0.752,
#   'vader_pos': 0.159,
#   'vader_compound': 0.9618,
#   'roberta_neg': 0.048887216,
#   'roberta_neu': 0.201512,
#   'roberta_pos': 0.74960077},
#  662983186: {'vader_neg': 0.0,
#   'vader_neu': 0.632,
#   'vader_pos': 0.368,
#   'vader_compound': 0.872,
#   'roberta_neg': 0.0017588405,
#   'roberta_neu': 0.017514123,
#   'roberta_pos': 0.9807271},
#  662945680: {'vader_neg': 0.0,
#   'vader_neu': 0.643,
#   'vader_pos': 0.357,
#   'vader_compound': 0.9231,
#   'roberta_neg': 0.0026504747,
#   'roberta_neu': 0.017183783,
#   'roberta_pos': 0.9801657},
#  662916382: {'vader_neg': 0.0,
#   'vader_neu': 0.803,
#   'vader_pos': 0.197,
#   'vader_compound': 0.9062,
#   'roberta_neg': 0.005065924,
#   'roberta_neu': 0.060808364,
#   'roberta_pos': 0.9341257},
#  662910647: {'vader_neg': 0.046,
#   'vader_neu': 0.782,
#   'vader_pos': 0.172,
#   'vader_compound': 0.9523,
#   'roberta_neg': 0.0050817723,
#   'roberta_neu': 0.03525717,
#   'roberta_pos': 0.959661},
#  662899563: {'vader_neg': 0.177,
#   'vader_neu': 0.737,
#   'vader_pos': 0.086,
#   'vader_compound': -0.9299,
#   'roberta_neg': 0.8035666,
#   'roberta_neu': 0.13880856,
#   'roberta_pos': 0.057624876},
#  662738160: {'vader_neg': 0.095,
#   'vader_neu': 0.824,
#   'vader_pos': 0.081,
#   'vader_compound': -0.7021,
#   'roberta_neg': 0.8211504,
#   'roberta_neu': 0.14805804,
#   'roberta_pos': 0.030791596},
#  662607741: {'vader_neg': 0.054,
#   'vader_neu': 0.77,
#   'vader_pos': 0.175,
#   'vader_compound': 0.7855,
#   'roberta_neg': 0.053201742,
#   'roberta_neu': 0.15217179,
#   'roberta_pos': 0.7946265},
#  662605883: {'vader_neg': 0.059,
#   'vader_neu': 0.701,
#   'vader_pos': 0.24,
#   'vader_compound': 0.839,
#   'roberta_neg': 0.12566374,
#   'roberta_neu': 0.1890136,
#   'roberta_pos': 0.68532264},
#  662599023: {'vader_neg': 0.06,
#   'vader_neu': 0.777,
#   'vader_pos': 0.164,
#   'vader_compound': 0.9431,
#   'roberta_neg': 0.015259633,
#   'roberta_neu': 0.060918096,
#   'roberta_pos': 0.9238222},
#  662586205: {'vader_neg': 0.0,
#   'vader_neu': 0.76,
#   'vader_pos': 0.24,
#   'vader_compound': 0.9276,
#   'roberta_neg': 0.003742022,
#   'roberta_neu': 0.01697563,
#   'roberta_pos': 0.9792823},
#  662545177: {'vader_neg': 0.008,
#   'vader_neu': 0.812,
#   'vader_pos': 0.18,
#   'vader_compound': 0.9846,
#   'roberta_neg': 0.0061724735,
#   'roberta_neu': 0.05962787,
#   'roberta_pos': 0.93419963},
#  662428253: {'vader_neg': 0.017,
#   'vader_neu': 0.861,
#   'vader_pos': 0.122,
#   'vader_compound': 0.9381,
#   'roberta_neg': 0.006619571,
#   'roberta_neu': 0.078503445,
#   'roberta_pos': 0.914877},
#  662299662: {'vader_neg': 0.0,
#   'vader_neu': 0.767,
#   'vader_pos': 0.233,
#   'vader_compound': 0.7845,
#   'roberta_neg': 0.001651868,
#   'roberta_neu': 0.011581532,
#   'roberta_pos': 0.9867666},
#  662254723: {'vader_neg': 0.036,
#   'vader_neu': 0.9,
#   'vader_pos': 0.063,
#   'vader_compound': 0.1875,
#   'roberta_neg': 0.026401551,
#   'roberta_neu': 0.096764036,
#   'roberta_pos': 0.8768344},
#  662063084: {'vader_neg': 0.046,
#   'vader_neu': 0.63,
#   'vader_pos': 0.323,
#   'vader_compound': 0.9623,
#   'roberta_neg': 0.021175418,
#   'roberta_neu': 0.11450225,
#   'roberta_pos': 0.86432236},
#  661954847: {'vader_neg': 0.017,
#   'vader_neu': 0.82,
#   'vader_pos': 0.163,
#   'vader_compound': 0.9489,
#   'roberta_neg': 0.03311536,
#   'roberta_neu': 0.17587592,
#   'roberta_pos': 0.7910087},
#  661951854: {'vader_neg': 0.126,
#   'vader_neu': 0.756,
#   'vader_pos': 0.118,
#   'vader_compound': 0.0757,
#   'roberta_neg': 0.5279426,
#   'roberta_neu': 0.31553882,
#   'roberta_pos': 0.15651861},
#  661932679: {'vader_neg': 0.025,
#   'vader_neu': 0.803,
#   'vader_pos': 0.172,
#   'vader_compound': 0.969,
#   'roberta_neg': 0.0017376409,
#   'roberta_neu': 0.010917261,
#   'roberta_pos': 0.98734504},
#  661925539: {'vader_neg': 0.083,
#   'vader_neu': 0.802,
#   'vader_pos': 0.115,
#   'vader_compound': 0.4516,
#   'roberta_neg': 0.9299766,
#   'roberta_neu': 0.061467342,
#   'roberta_pos': 0.008556145},
#  661874846: {'vader_neg': 0.087,
#   'vader_neu': 0.892,
#   'vader_pos': 0.021,
#   'vader_compound': -0.7925,
#   'roberta_neg': 0.6721167,
#   'roberta_neu': 0.27298152,
#   'roberta_pos': 0.054901704},
#  661809959: {'vader_neg': 0.054,
#   'vader_neu': 0.754,
#   'vader_pos': 0.192,
#   'vader_compound': 0.86,
#   'roberta_neg': 0.0026403777,
#   'roberta_neu': 0.028591176,
#   'roberta_pos': 0.9687685},
#  661706045: {'vader_neg': 0.0,
#   'vader_neu': 0.664,
#   'vader_pos': 0.336,
#   'vader_compound': 0.8621,
#   'roberta_neg': 0.0016283885,
#   'roberta_neu': 0.016877217,
#   'roberta_pos': 0.9814944},
#  661650072: {'vader_neg': 0.102,
#   'vader_neu': 0.863,
#   'vader_pos': 0.035,
#   'vader_compound': -0.7906,
#   'roberta_neg': 0.86023676,
#   'roberta_neu': 0.11747441,
#   'roberta_pos': 0.022288894},
#  661471123: {'vader_neg': 0.032,
#   'vader_neu': 0.848,
#   'vader_pos': 0.121,
#   'vader_compound': 0.7935,
#   'roberta_neg': 0.007930979,
#   'roberta_neu': 0.05204192,
#   'roberta_pos': 0.94002706},
#  661455978: {'vader_neg': 0.065,
#   'vader_neu': 0.819,
#   'vader_pos': 0.116,
#   'vader_compound': 0.3269,
#   'roberta_neg': 0.16813624,
#   'roberta_neu': 0.31451035,
#   'roberta_pos': 0.5173534},
#  661407944: {'vader_neg': 0.041,
#   'vader_neu': 0.877,
#   'vader_pos': 0.083,
#   'vader_compound': 0.916,
#   'roberta_neg': 0.12057552,
#   'roberta_neu': 0.42943797,
#   'roberta_pos': 0.44998652},
#  661375942: {'vader_neg': 0.062,
#   'vader_neu': 0.788,
#   'vader_pos': 0.15,
#   'vader_compound': 0.9372,
#   'roberta_neg': 0.058157146,
#   'roberta_neu': 0.16731715,
#   'roberta_pos': 0.7745257},
#  661256360: {'vader_neg': 0.0,
#   'vader_neu': 0.824,
#   'vader_pos': 0.176,
#   'vader_compound': 0.9412,
#   'roberta_neg': 0.0026624394,
#   'roberta_neu': 0.022356454,
#   'roberta_pos': 0.9749811},
#  661247430: {'vader_neg': 0.08,
#   'vader_neu': 0.788,
#   'vader_pos': 0.132,
#   'vader_compound': 0.9154,
#   'roberta_neg': 0.3087441,
#   'roberta_neu': 0.36986876,
#   'roberta_pos': 0.3213871},
#  661175008: {'vader_neg': 0.0,
#   'vader_neu': 0.747,
#   'vader_pos': 0.253,
#   'vader_compound': 0.996,
#   'roberta_neg': 0.001362585,
#   'roberta_neu': 0.010830616,
#   'roberta_pos': 0.98780674},
#  661121224: {'vader_neg': 0.0,
#   'vader_neu': 0.656,
#   'vader_pos': 0.344,
#   'vader_compound': 0.9702,
#   'roberta_neg': 0.0015453662,
#   'roberta_neu': 0.01048682,
#   'roberta_pos': 0.9879677},
#  660934678: {'vader_neg': 0.136,
#   'vader_neu': 0.864,
#   'vader_pos': 0.0,
#   'vader_compound': -0.6887,
#   'roberta_neg': 0.080068626,
#   'roberta_neu': 0.34615195,
#   'roberta_pos': 0.5737794},
#  660798525: {'vader_neg': 0.0,
#   'vader_neu': 0.84,
#   'vader_pos': 0.16,
#   'vader_compound': 0.9838,
#   'roberta_neg': 0.0069099474,
#   'roberta_neu': 0.025700701,
#   'roberta_pos': 0.9673893},
#  660777542: {'vader_neg': 0.027,
#   'vader_neu': 0.826,
#   'vader_pos': 0.147,
#   'vader_compound': 0.8739,
#   'roberta_neg': 0.030384855,
#   'roberta_neu': 0.09169763,
#   'roberta_pos': 0.8779175},
#  660639172: {'vader_neg': 0.0,
#   'vader_neu': 0.661,
#   'vader_pos': 0.339,
#   'vader_compound': 0.9157,
#   'roberta_neg': 0.0050641135,
#   'roberta_neu': 0.009819425,
#   'roberta_pos': 0.98511654},
#  660628754: {'vader_neg': 0.088,
#   'vader_neu': 0.761,
#   'vader_pos': 0.151,
#   'vader_compound': 0.7003,
#   'roberta_neg': 0.017195309,
#   'roberta_neu': 0.066882335,
#   'roberta_pos': 0.9159224},
#  660547275: {'vader_neg': 0.063,
#   'vader_neu': 0.82,
#   'vader_pos': 0.117,
#   'vader_compound': 0.9547,
#   'roberta_neg': 0.054667033,
#   'roberta_neu': 0.24785566,
#   'roberta_pos': 0.6974773},
#  660261214: {'vader_neg': 0.0,
#   'vader_neu': 0.831,
#   'vader_pos': 0.169,
#   'vader_compound': 0.9878,
#   'roberta_neg': 0.0017151722,
#   'roberta_neu': 0.0141878715,
#   'roberta_pos': 0.984097},
#  660256198: {'vader_neg': 0.014,
#   'vader_neu': 0.744,
#   'vader_pos': 0.242,
#   'vader_compound': 0.9783,
#   'roberta_neg': 0.00506718,
#   'roberta_neu': 0.025360469,
#   'roberta_pos': 0.96957237},
#  660227869: {'vader_neg': 0.101,
#   'vader_neu': 0.721,
#   'vader_pos': 0.179,
#   'vader_compound': 0.357,
#   'roberta_neg': 0.021185651,
#   'roberta_neu': 0.1546479,
#   'roberta_pos': 0.8241665},
#  660037386: {'vader_neg': 0.037,
#   'vader_neu': 0.75,
#   'vader_pos': 0.213,
#   'vader_compound': 0.966,
#   'roberta_neg': 0.0014606171,
#   'roberta_neu': 0.008507253,
#   'roberta_pos': 0.9900322},
#  660012508: {'vader_neg': 0.0,
#   'vader_neu': 0.697,
#   'vader_pos': 0.303,
#   'vader_compound': 0.9299,
#   'roberta_neg': 0.0018782865,
#   'roberta_neu': 0.01566204,
#   'roberta_pos': 0.98245966},
#  659959030: {'vader_neg': 0.024,
#   'vader_neu': 0.843,
#   'vader_pos': 0.132,
#   'vader_compound': 0.9421,
#   'roberta_neg': 0.0024389944,
#   'roberta_neu': 0.011852647,
#   'roberta_pos': 0.98570836},
#  659956711: {'vader_neg': 0.035,
#   'vader_neu': 0.681,
#   'vader_pos': 0.284,
#   'vader_compound': 0.9432,
#   'roberta_neg': 0.0032484108,
#   'roberta_neu': 0.014842079,
#   'roberta_pos': 0.9819095},
#  659780911: {'vader_neg': 0.168,
#   'vader_neu': 0.724,
#   'vader_pos': 0.108,
#   'vader_compound': -0.9616,
#   'roberta_neg': 0.65341383,
#   'roberta_neu': 0.22594,
#   'roberta_pos': 0.12064617},
#  659756810: {'vader_neg': 0.0,
#   'vader_neu': 0.646,
#   'vader_pos': 0.354,
#   'vader_compound': 0.9423,
#   'roberta_neg': 0.0009894612,
#   'roberta_neu': 0.013946976,
#   'roberta_pos': 0.98506355},
#  659744831: {'vader_neg': 0.03,
#   'vader_neu': 0.76,
#   'vader_pos': 0.21,
#   'vader_compound': 0.9337,
#   'roberta_neg': 0.009615821,
#   'roberta_neu': 0.024597455,
#   'roberta_pos': 0.9657867},
#  659743835: {'vader_neg': 0.143,
#   'vader_neu': 0.812,
#   'vader_pos': 0.045,
#   'vader_compound': -0.69,
#   'roberta_neg': 0.7455831,
#   'roberta_neu': 0.18307726,
#   'roberta_pos': 0.07133965},
#  659712280: {'vader_neg': 0.0,
#   'vader_neu': 0.858,
#   'vader_pos': 0.142,
#   'vader_compound': 0.8078,
#   'roberta_neg': 0.0017768865,
#   'roberta_neu': 0.01568619,
#   'roberta_pos': 0.98253685},
#  659631322: {'vader_neg': 0.041,
#   'vader_neu': 0.884,
#   'vader_pos': 0.074,
#   'vader_compound': 0.3071,
#   'roberta_neg': 0.020198854,
#   'roberta_neu': 0.17323598,
#   'roberta_pos': 0.8065652},
#  659595153: {'vader_neg': 0.0,
#   'vader_neu': 0.909,
#   'vader_pos': 0.091,
#   'vader_compound': 0.5983,
#   'roberta_neg': 0.0015860166,
#   'roberta_neu': 0.010663856,
#   'roberta_pos': 0.9877501},
#  659547279: {'vader_neg': 0.0,
#   'vader_neu': 1.0,
#   'vader_pos': 0.0,
#   'vader_compound': 0.0,
#   'roberta_neg': 0.00222903,
#   'roberta_neu': 0.01980205,
#   'roberta_pos': 0.977969},
#  659537079: {'vader_neg': 0.033,
#   'vader_neu': 0.781,
#   'vader_pos': 0.186,
#   'vader_compound': 0.8405,
#   'roberta_neg': 0.0030672057,
#   'roberta_neu': 0.010105181,
#   'roberta_pos': 0.9868276},
#  659394961: {'vader_neg': 0.0,
#   'vader_neu': 0.796,
#   'vader_pos': 0.204,
#   'vader_compound': 0.8665,
#   'roberta_neg': 0.0020188536,
#   'roberta_neu': 0.006005802,
#   'roberta_pos': 0.99197537},
#  659394290: {'vader_neg': 0.012,
#   'vader_neu': 0.749,
#   'vader_pos': 0.24,
#   'vader_compound': 0.9792,
#   'roberta_neg': 0.0011084947,
#   'roberta_neu': 0.009498759,
#   'roberta_pos': 0.98939276},
#  659355424: {'vader_neg': 0.084,
#   'vader_neu': 0.766,
#   'vader_pos': 0.15,
#   'vader_compound': 0.6479,
#   'roberta_neg': 0.0033760488,
#   'roberta_neu': 0.005959563,
#   'roberta_pos': 0.99066436},
#  659354552: {'vader_neg': 0.136,
#   'vader_neu': 0.738,
#   'vader_pos': 0.127,
#   'vader_compound': -0.8797,
#   'roberta_neg': 0.6457616,
#   'roberta_neu': 0.281077,
#   'roberta_pos': 0.073161356},
#  659287317: {'vader_neg': 0.0,
#   'vader_neu': 0.816,
#   'vader_pos': 0.184,
#   'vader_compound': 0.9628,
#   'roberta_neg': 0.0013578536,
#   'roberta_neu': 0.0117261,
#   'roberta_pos': 0.98691607},
#  659080088: {'vader_neg': 0.012,
#   'vader_neu': 0.863,
#   'vader_pos': 0.125,
#   'vader_compound': 0.9382,
#   'roberta_neg': 0.02195668,
#   'roberta_neu': 0.22208953,
#   'roberta_pos': 0.75595385},
#  659058646: {'vader_neg': 0.0,
#   'vader_neu': 0.867,
#   'vader_pos': 0.133,
#   'vader_compound': 0.6124,
#   'roberta_neg': 0.088599704,
#   'roberta_neu': 0.39535496,
#   'roberta_pos': 0.51604533},
#  659054990: {'vader_neg': 0.123,
#   'vader_neu': 0.76,
#   'vader_pos': 0.117,
#   'vader_compound': -0.1469,
#   'roberta_neg': 0.9641813,
#   'roberta_neu': 0.031563856,
#   'roberta_pos': 0.0042547984},
#  659015104: {'vader_neg': 0.011,
#   'vader_neu': 0.802,
#   'vader_pos': 0.187,
#   'vader_compound': 0.9942,
#   'roberta_neg': 0.016730903,
#   'roberta_neu': 0.10526533,
#   'roberta_pos': 0.8780038},
#  658941446: {'vader_neg': 0.02,
#   'vader_neu': 0.808,
#   'vader_pos': 0.172,
#   'vader_compound': 0.9904,
#   'roberta_neg': 0.015009118,
#   'roberta_neu': 0.087578595,
#   'roberta_pos': 0.8974123},
#  658923313: {'vader_neg': 0.0,
#   'vader_neu': 0.74,
#   'vader_pos': 0.26,
#   'vader_compound': 0.9738,
#   'roberta_neg': 0.00123119,
#   'roberta_neu': 0.008293621,
#   'roberta_pos': 0.99047524},
#  658851325: {'vader_neg': 0.073,
#   'vader_neu': 0.902,
#   'vader_pos': 0.026,
#   'vader_compound': -0.832,
#   'roberta_neg': 0.65506697,
#   'roberta_neu': 0.26213408,
#   'roberta_pos': 0.08279896},
#  658829077: {'vader_neg': 0.0,
#   'vader_neu': 0.785,
#   'vader_pos': 0.215,
#   'vader_compound': 0.8911,
#   'roberta_neg': 0.0013530746,
#   'roberta_neu': 0.0127200475,
#   'roberta_pos': 0.98592687},
#  658806813: {'vader_neg': 0.072,
#   'vader_neu': 0.798,
#   'vader_pos': 0.13,
#   'vader_compound': 0.7131,
#   'roberta_neg': 0.03867678,
#   'roberta_neu': 0.13888164,
#   'roberta_pos': 0.8224416},
#  658749359: {'vader_neg': 0.019,
#   'vader_neu': 0.783,
#   'vader_pos': 0.198,
#   'vader_compound': 0.9116,
#   'roberta_neg': 0.0041019293,
#   'roberta_neu': 0.023203047,
#   'roberta_pos': 0.972695},
#  658670526: {'vader_neg': 0.0,
#   'vader_neu': 0.64,
#   'vader_pos': 0.36,
#   'vader_compound': 0.9799,
#   'roberta_neg': 0.0017611719,
#   'roberta_neu': 0.010595877,
#   'roberta_pos': 0.987643},
#  658632460: {'vader_neg': 0.0,
#   'vader_neu': 0.823,
#   'vader_pos': 0.177,
#   'vader_compound': 0.9091,
#   'roberta_neg': 0.0020607898,
#   'roberta_neu': 0.02260886,
#   'roberta_pos': 0.9753304},
#  658541133: {'vader_neg': 0.0,
#   'vader_neu': 0.74,
#   'vader_pos': 0.26,
#   'vader_compound': 0.9623,
#   'roberta_neg': 0.0018582458,
#   'roberta_neu': 0.011398094,
#   'roberta_pos': 0.9867437},
#  658296146: {'vader_neg': 0.029,
#   'vader_neu': 0.886,
#   'vader_pos': 0.085,
#   'vader_compound': 0.9709,
#   'roberta_neg': 0.014093158,
#   'roberta_neu': 0.1499599,
#   'roberta_pos': 0.8359469},
#  658286408: {'vader_neg': 0.045,
#   'vader_neu': 0.81,
#   'vader_pos': 0.146,
#   'vader_compound': 0.9969,
#   'roberta_neg': 0.007322107,
#   'roberta_neu': 0.057631016,
#   'roberta_pos': 0.93504685},
#  658055158: {'vader_neg': 0.0,
#   'vader_neu': 0.814,
#   'vader_pos': 0.186,
#   'vader_compound': 0.9371,
#   'roberta_neg': 0.0030601246,
#   'roberta_neu': 0.015027689,
#   'roberta_pos': 0.98191214},
#  657949392: {'vader_neg': 0.0,
#   'vader_neu': 0.804,
#   'vader_pos': 0.196,
#   'vader_compound': 0.83,
#   'roberta_neg': 0.0022437943,
#   'roberta_neu': 0.016005851,
#   'roberta_pos': 0.98175037},
#  657859084: {'vader_neg': 0.0,
#   'vader_neu': 0.89,
#   'vader_pos': 0.11,
#   'vader_compound': 0.6531,
#   'roberta_neg': 0.003773281,
#   'roberta_neu': 0.0794627,
#   'roberta_pos': 0.916764},
#  657714323: {'vader_neg': 0.047,
#   'vader_neu': 0.817,
#   'vader_pos': 0.136,
#   'vader_compound': 0.5216,
#   'roberta_neg': 0.002389559,
#   'roberta_neu': 0.007738436,
#   'roberta_pos': 0.98987204},
#  657660194: {'vader_neg': 0.088,
#   'vader_neu': 0.794,
#   'vader_pos': 0.117,
#   'vader_compound': 0.7396,
#   'roberta_neg': 0.0160653,
#   'roberta_neu': 0.044654824,
#   'roberta_pos': 0.93927985},
#  657655448: {'vader_neg': 0.056,
#   'vader_neu': 0.528,
#   'vader_pos': 0.416,
#   'vader_compound': 0.9701,
#   'roberta_neg': 0.0022714227,
#   'roberta_neu': 0.004776984,
#   'roberta_pos': 0.9929516},
#  657628630: {'vader_neg': 0.081,
#   'vader_neu': 0.695,
#   'vader_pos': 0.224,
#   'vader_compound': 0.9703,
#   'roberta_neg': 0.0014895769,
#   'roberta_neu': 0.017504768,
#   'roberta_pos': 0.98100567},
#  657597383: {'vader_neg': 0.193,
#   'vader_neu': 0.807,
#   'vader_pos': 0.0,
#   'vader_compound': -0.7717,
#   'roberta_neg': 0.0015826789,
#   'roberta_neu': 0.03956816,
#   'roberta_pos': 0.9588492},
#  657484047: {'vader_neg': 0.034,
#   'vader_neu': 0.794,
#   'vader_pos': 0.172,
#   'vader_compound': 0.8435,
#   'roberta_neg': 0.005215464,
#   'roberta_neu': 0.042670596,
#   'roberta_pos': 0.95211387},
#  657463469: {'vader_neg': 0.025,
#   'vader_neu': 0.604,
#   'vader_pos': 0.37,
#   'vader_compound': 0.9939,
#   'roberta_neg': 0.061733045,
#   'roberta_neu': 0.24528618,
#   'roberta_pos': 0.69298077},
#  657450717: {'vader_neg': 0.094,
#   'vader_neu': 0.733,
#   'vader_pos': 0.173,
#   'vader_compound': 0.9677,
#   'roberta_neg': 0.0036850304,
#   'roberta_neu': 0.031013256,
#   'roberta_pos': 0.9653017},
#  657440194: {'vader_neg': 0.011,
#   'vader_neu': 0.707,
#   'vader_pos': 0.282,
#   'vader_compound': 0.9795,
#   'roberta_neg': 0.0026936436,
#   'roberta_neu': 0.014296361,
#   'roberta_pos': 0.98301},
#  657427577: {'vader_neg': 0.111,
#   'vader_neu': 0.748,
#   'vader_pos': 0.141,
#   'vader_compound': 0.5719,
#   'roberta_neg': 0.06561405,
#   'roberta_neu': 0.25772816,
#   'roberta_pos': 0.6766578},
#  657422390: {'vader_neg': 0.0,
#   'vader_neu': 0.879,
#   'vader_pos': 0.121,
#   'vader_compound': 0.7251,
#   'roberta_neg': 0.12937704,
#   'roberta_neu': 0.20155807,
#   'roberta_pos': 0.6690649},
#  657216865: {'vader_neg': 0.011,
#   'vader_neu': 0.806,
#   'vader_pos': 0.182,
#   'vader_compound': 0.9919,
#   'roberta_neg': 0.006282736,
#   'roberta_neu': 0.052043915,
#   'roberta_pos': 0.94167334},
#  657110215: {'vader_neg': 0.0,
#   'vader_neu': 0.879,
#   'vader_pos': 0.121,
#   'vader_compound': 0.6696,
#   'roberta_neg': 0.0012987402,
#   'roberta_neu': 0.019009229,
#   'roberta_pos': 0.97969204},
#  656988387: {'vader_neg': 0.058,
#   'vader_neu': 0.794,
#   'vader_pos': 0.149,
#   'vader_compound': 0.5499,
#   'roberta_neg': 0.028764779,
#   'roberta_neu': 0.22013657,
#   'roberta_pos': 0.7510987},
#  656984955: {'vader_neg': 0.031,
#   'vader_neu': 0.725,
#   'vader_pos': 0.244,
#   'vader_compound': 0.9787,
#   'roberta_neg': 0.001629282,
#   'roberta_neu': 0.0060913595,
#   'roberta_pos': 0.9922794},
#  656869450: {'vader_neg': 0.0,
#   'vader_neu': 0.819,
#   'vader_pos': 0.181,
#   'vader_compound': 0.926,
#   'roberta_neg': 0.0013735852,
#   'roberta_neu': 0.00901662,
#   'roberta_pos': 0.98960984},
#  656807678: {'vader_neg': 0.042,
#   'vader_neu': 0.856,
#   'vader_pos': 0.102,
#   'vader_compound': 0.9728,
#   'roberta_neg': 0.01538275,
#   'roberta_neu': 0.15223517,
#   'roberta_pos': 0.832382},
#  656777839: {'vader_neg': 0.0,
#   'vader_neu': 0.85,
#   'vader_pos': 0.15,
#   'vader_compound': 0.8836,
#   'roberta_neg': 0.2659149,
#   'roberta_neu': 0.39222497,
#   'roberta_pos': 0.34186018},
#  656620593: {'vader_neg': 0.0,
#   'vader_neu': 0.768,
#   'vader_pos': 0.232,
#   'vader_compound': 0.953,
#   'roberta_neg': 0.0016729853,
#   'roberta_neu': 0.007752818,
#   'roberta_pos': 0.9905742},
#  656527999: {'vader_neg': 0.04,
#   'vader_neu': 0.67,
#   'vader_pos': 0.291,
#   'vader_compound': 0.8883,
#   'roberta_neg': 0.003645988,
#   'roberta_neu': 0.021297995,
#   'roberta_pos': 0.97505605},
#  656429953: {'vader_neg': 0.0,
#   'vader_neu': 0.735,
#   'vader_pos': 0.265,
#   'vader_compound': 0.9229,
#   'roberta_neg': 0.0033416892,
#   'roberta_neu': 0.023484185,
#   'roberta_pos': 0.9731741},
#  656359818: {'vader_neg': 0.0,
#   'vader_neu': 0.748,
#   'vader_pos': 0.252,
#   'vader_compound': 0.9476,
#   'roberta_neg': 0.0011471281,
#   'roberta_neu': 0.008111152,
#   'roberta_pos': 0.9907417},
#  656174585: {'vader_neg': 0.0,
#   'vader_neu': 0.861,
#   'vader_pos': 0.139,
#   'vader_compound': 0.8979,
#   'roberta_neg': 0.01799393,
#   'roberta_neu': 0.11338139,
#   'roberta_pos': 0.8686247},
#  656153366: {'vader_neg': 0.0,
#   'vader_neu': 0.79,
#   'vader_pos': 0.21,
#   'vader_compound': 0.7964,
#   'roberta_neg': 0.006392835,
#   'roberta_neu': 0.04586761,
#   'roberta_pos': 0.9477396},
#  656152930: {'vader_neg': 0.0,
#   'vader_neu': 0.635,
#   'vader_pos': 0.365,
#   'vader_compound': 0.8885,
#   'roberta_neg': 0.00170188,
#   'roberta_neu': 0.014499341,
#   'roberta_pos': 0.98379874},
#  656146924: {'vader_neg': 0.0,
#   'vader_neu': 0.792,
#   'vader_pos': 0.208,
#   'vader_compound': 0.8591,
#   'roberta_neg': 0.0064625726,
#   'roberta_neu': 0.07060788,
#   'roberta_pos': 0.9229295},
#  656135656: {'vader_neg': 0.052,
#   'vader_neu': 0.826,
#   'vader_pos': 0.123,
#   'vader_compound': 0.7845,
#   'roberta_neg': 0.095957905,
#   'roberta_neu': 0.19147588,
#   'roberta_pos': 0.71256626},
#  656118691: {'vader_neg': 0.135,
#   'vader_neu': 0.62,
#   'vader_pos': 0.245,
#   'vader_compound': 0.8764,
#   'roberta_neg': 0.005541166,
#   'roberta_neu': 0.027010903,
#   'roberta_pos': 0.9674479},
#  656088536: {'vader_neg': 0.03,
#   'vader_neu': 0.952,
#   'vader_pos': 0.018,
#   'vader_compound': -0.2942,
#   'roberta_neg': 0.5116938,
#   'roberta_neu': 0.3735359,
#   'roberta_pos': 0.114770375},
#  656074759: {'vader_neg': 0.0,
#   'vader_neu': 0.785,
#   'vader_pos': 0.215,
#   'vader_compound': 0.6689,
#   'roberta_neg': 0.0034526088,
#   'roberta_neu': 0.051157065,
#   'roberta_pos': 0.9453903},
#  656063047: {'vader_neg': 0.029,
#   'vader_neu': 0.787,
#   'vader_pos': 0.184,
#   'vader_compound': 0.9994,
#   'roberta_neg': 0.114158265,
#   'roberta_neu': 0.32597357,
#   'roberta_pos': 0.55986816},
#  655920863: {'vader_neg': 0.007,
#   'vader_neu': 0.831,
#   'vader_pos': 0.162,
#   'vader_compound': 0.9916,
#   'roberta_neg': 0.005426672,
#   'roberta_neu': 0.04349051,
#   'roberta_pos': 0.95108277},
#  655909494: {'vader_neg': 0.19,
#   'vader_neu': 0.49,
#   'vader_pos': 0.32,
#   'vader_compound': 0.6449,
#   'roberta_neg': 0.0057940064,
#   'roberta_neu': 0.018952413,
#   'roberta_pos': 0.97525364},
#  655721400: {'vader_neg': 0.104,
#   'vader_neu': 0.804,
#   'vader_pos': 0.092,
#   'vader_compound': -0.339,
#   'roberta_neg': 0.45975173,
#   'roberta_neu': 0.39151525,
#   'roberta_pos': 0.1487331},
#  655713970: {'vader_neg': 0.035,
#   'vader_neu': 0.811,
#   'vader_pos': 0.154,
#   'vader_compound': 0.9974,
#   'roberta_neg': 0.004579945,
#   'roberta_neu': 0.09792747,
#   'roberta_pos': 0.8974925},
#  655711519: {'vader_neg': 0.0,
#   'vader_neu': 0.66,
#   'vader_pos': 0.34,
#   'vader_compound': 0.978,
#   'roberta_neg': 0.001544023,
#   'roberta_neu': 0.016513215,
#   'roberta_pos': 0.9819427},
#  655698974: {'vader_neg': 0.016,
#   'vader_neu': 0.763,
#   'vader_pos': 0.221,
#   'vader_compound': 0.9354,
#   'roberta_neg': 0.0025070268,
#   'roberta_neu': 0.017563868,
#   'roberta_pos': 0.97992915},
#  655667191: {'vader_neg': 0.165,
#   'vader_neu': 0.714,
#   'vader_pos': 0.121,
#   'vader_compound': -0.4215,
#   'roberta_neg': 0.0031751227,
#   'roberta_neu': 0.04103086,
#   'roberta_pos': 0.955794},
#  655666069: {'vader_neg': 0.039,
#   'vader_neu': 0.689,
#   'vader_pos': 0.273,
#   'vader_compound': 0.9538,
#   'roberta_neg': 0.0013374028,
#   'roberta_neu': 0.009626913,
#   'roberta_pos': 0.98903567},
#  655530915: {'vader_neg': 0.056,
#   'vader_neu': 0.764,
#   'vader_pos': 0.18,
#   'vader_compound': 0.8813,
#   'roberta_neg': 0.0032939904,
#   'roberta_neu': 0.011911205,
#   'roberta_pos': 0.9847948},
#  655438918: {'vader_neg': 0.068,
#   'vader_neu': 0.751,
#   'vader_pos': 0.182,
#   'vader_compound': 0.9659,
#   'roberta_neg': 0.13548484,
#   'roberta_neu': 0.18166892,
#   'roberta_pos': 0.6828462},
#  655421651: {'vader_neg': 0.023,
#   'vader_neu': 0.737,
#   'vader_pos': 0.239,
#   'vader_compound': 0.9903,
#   'roberta_neg': 0.0032521943,
#   'roberta_neu': 0.012244181,
#   'roberta_pos': 0.9845036},
#  655317892: {'vader_neg': 0.184,
#   'vader_neu': 0.655,
#   'vader_pos': 0.161,
#   'vader_compound': 0.297,
#   'roberta_neg': 0.2529156,
#   'roberta_neu': 0.29609567,
#   'roberta_pos': 0.4509888},
#  655304949: {'vader_neg': 0.112,
#   'vader_neu': 0.825,
#   'vader_pos': 0.063,
#   'vader_compound': -0.7644,
#   'roberta_neg': 0.8273515,
#   'roberta_neu': 0.1424421,
#   'roberta_pos': 0.030206367},
#  655278938: {'vader_neg': 0.065,
#   'vader_neu': 0.855,
#   'vader_pos': 0.08,
#   'vader_compound': 0.5487,
#   'roberta_neg': 0.49953088,
#   'roberta_neu': 0.34338567,
#   'roberta_pos': 0.15708345},
#  655139603: {'vader_neg': 0.081,
#   'vader_neu': 0.892,
#   'vader_pos': 0.027,
#   'vader_compound': -0.7469,
#   'roberta_neg': 0.72224015,
#   'roberta_neu': 0.21302621,
#   'roberta_pos': 0.064733595},
#  655118462: {'vader_neg': 0.026,
#   'vader_neu': 0.793,
#   'vader_pos': 0.181,
#   'vader_compound': 0.9118,
#   'roberta_neg': 0.002372868,
#   'roberta_neu': 0.009668637,
#   'roberta_pos': 0.98795843},
#  655083570: {'vader_neg': 0.035,
#   'vader_neu': 0.856,
#   'vader_pos': 0.109,
#   'vader_compound': 0.9802,
#   'roberta_neg': 0.051377453,
#   'roberta_neu': 0.24891496,
#   'roberta_pos': 0.69970757},
#  654869307: {'vader_neg': 0.0,
#   'vader_neu': 0.616,
#   'vader_pos': 0.384,
#   'vader_compound': 0.9862,
#   'roberta_neg': 0.0022022377,
#   'roberta_neu': 0.0060145287,
#   'roberta_pos': 0.99178326},
#  654861800: {'vader_neg': 0.0,
#   'vader_neu': 0.576,
#   'vader_pos': 0.424,
#   'vader_compound': 0.9403,
#   'roberta_neg': 0.0018839054,
#   'roberta_neu': 0.00759906,
#   'roberta_pos': 0.9905171},
#  654801936: {'vader_neg': 0.0,
#   'vader_neu': 0.729,
#   'vader_pos': 0.271,
#   'vader_compound': 0.836,
#   'roberta_neg': 0.0027633256,
#   'roberta_neu': 0.036134,
#   'roberta_pos': 0.96110266},
#  654638219: {'vader_neg': 0.059,
#   'vader_neu': 0.888,
#   'vader_pos': 0.054,
#   'vader_compound': -0.2617,
#   'roberta_neg': 0.02410352,
#   'roberta_neu': 0.15679169,
#   'roberta_pos': 0.8191048},
#  654567840: {'vader_neg': 0.0,
#   'vader_neu': 0.686,
#   'vader_pos': 0.314,
#   'vader_compound': 0.8772,
#   'roberta_neg': 0.0016391613,
#   'roberta_neu': 0.00627739,
#   'roberta_pos': 0.99208343},
#  654552915: {'vader_neg': 0.046,
#   'vader_neu': 0.811,
#   'vader_pos': 0.143,
#   'vader_compound': 0.8768,
#   'roberta_neg': 0.0030172223,
#   'roberta_neu': 0.0589685,
#   'roberta_pos': 0.93801427},
#  654548402: {'vader_neg': 0.062,
#   'vader_neu': 0.814,
#   'vader_pos': 0.124,
#   'vader_compound': 0.5619,
#   'roberta_neg': 0.14501143,
#   'roberta_neu': 0.26184952,
#   'roberta_pos': 0.59313905},
#  654325473: {'vader_neg': 0.068,
#   'vader_neu': 0.721,
#   'vader_pos': 0.211,
#   'vader_compound': 0.8464,
#   'roberta_neg': 0.0028849114,
#   'roberta_neu': 0.02780353,
#   'roberta_pos': 0.96931154},
#  654308388: {'vader_neg': 0.018,
#   'vader_neu': 0.861,
#   'vader_pos': 0.121,
#   'vader_compound': 0.9155,
#   'roberta_neg': 0.0024596427,
#   'roberta_neu': 0.018463364,
#   'roberta_pos': 0.979077},
#  654214434: {'vader_neg': 0.055,
#   'vader_neu': 0.858,
#   'vader_pos': 0.088,
#   'vader_compound': 0.1779,
#   'roberta_neg': 0.010089173,
#   'roberta_neu': 0.058197144,
#   'roberta_pos': 0.9317137},
#  654165819: {'vader_neg': 0.086,
#   'vader_neu': 0.827,
#   'vader_pos': 0.087,
#   'vader_compound': 0.0258,
#   'roberta_neg': 0.41736385,
#   'roberta_neu': 0.36437112,
#   'roberta_pos': 0.21826501},
#  654020003: {'vader_neg': 0.097,
#   'vader_neu': 0.739,
#   'vader_pos': 0.164,
#   'vader_compound': 0.6705,
#   'roberta_neg': 0.041636836,
#   'roberta_neu': 0.082095146,
#   'roberta_pos': 0.87626797},
#  653846728: {'vader_neg': 0.114,
#   'vader_neu': 0.848,
#   'vader_pos': 0.038,
#   'vader_compound': -0.958,
#   'roberta_neg': 0.947957,
#   'roberta_neu': 0.044777546,
#   'roberta_pos': 0.007265449},
#  653820439: {'vader_neg': 0.0,
#   'vader_neu': 0.684,
#   'vader_pos': 0.316,
#   'vader_compound': 0.9354,
#   'roberta_neg': 0.0016997791,
#   'roberta_neu': 0.014536015,
#   'roberta_pos': 0.98376423},
#  653794695: {'vader_neg': 0.0,
#   'vader_neu': 0.695,
#   'vader_pos': 0.305,
#   'vader_compound': 0.9648,
#   'roberta_neg': 0.001658796,
#   'roberta_neu': 0.010154997,
#   'roberta_pos': 0.98818624},
#  653792189: {'vader_neg': 0.0,
#   'vader_neu': 0.934,
#   'vader_pos': 0.066,
#   'vader_compound': 0.5106,
#   'roberta_neg': 0.0018645962,
#   'roberta_neu': 0.027515557,
#   'roberta_pos': 0.9706198},
#  653785535: {'vader_neg': 0.0,
#   'vader_neu': 0.873,
#   'vader_pos': 0.127,
#   'vader_compound': 0.9891,
#   'roberta_neg': 0.0026157484,
#   'roberta_neu': 0.0283403,
#   'roberta_pos': 0.9690439},
#  653729947: {'vader_neg': 0.023,
#   'vader_neu': 0.734,
#   'vader_pos': 0.243,
#   'vader_compound': 0.9473,
#   'roberta_neg': 0.0014717452,
#   'roberta_neu': 0.008289201,
#   'roberta_pos': 0.990239},
#  653717283: {'vader_neg': 0.0,
#   'vader_neu': 0.707,
#   'vader_pos': 0.293,
#   'vader_compound': 0.9813,
#   'roberta_neg': 0.0018791448,
#   'roberta_neu': 0.005492219,
#   'roberta_pos': 0.9926286},
#  653705474: {'vader_neg': 0.057,
#   'vader_neu': 0.725,
#   'vader_pos': 0.218,
#   'vader_compound': 0.775,
#   'roberta_neg': 0.03332925,
#   'roberta_neu': 0.07752923,
#   'roberta_pos': 0.8891415},
#  653487396: {'vader_neg': 0.021,
#   'vader_neu': 0.817,
#   'vader_pos': 0.162,
#   'vader_compound': 0.9826,
#   'roberta_neg': 0.005441628,
#   'roberta_neu': 0.03746678,
#   'roberta_pos': 0.95709157},
#  653377199: {'vader_neg': 0.0,
#   'vader_neu': 0.607,
#   'vader_pos': 0.393,
#   'vader_compound': 0.9749,
#   'roberta_neg': 0.0013123915,
#   'roberta_neu': 0.006235851,
#   'roberta_pos': 0.9924517},
#  653110061: {'vader_neg': 0.022,
#   'vader_neu': 0.747,
#   'vader_pos': 0.23,
#   'vader_compound': 0.9976,
#   'roberta_neg': 0.0020827402,
#   'roberta_neu': 0.048232127,
#   'roberta_pos': 0.94968516},
#  652882557: {'vader_neg': 0.0,
#   'vader_neu': 0.816,
#   'vader_pos': 0.184,
#   'vader_compound': 0.8442,
#   'roberta_neg': 0.0016601408,
#   'roberta_neu': 0.0084749665,
#   'roberta_pos': 0.9898649},
#  652849123: {'vader_neg': 0.047,
#   'vader_neu': 0.878,
#   'vader_pos': 0.074,
#   'vader_compound': 0.7858,
#   'roberta_neg': 0.029071506,
#   'roberta_neu': 0.3222109,
#   'roberta_pos': 0.6487176},
#  652757690: {'vader_neg': 0.0,
#   'vader_neu': 0.181,
#   'vader_pos': 0.819,
#   'vader_compound': 0.9858,
#   'roberta_neg': 0.0017374816,
#   'roberta_neu': 0.0161761,
#   'roberta_pos': 0.9820864},
#  652613974: {'vader_neg': 0.0,
#   'vader_neu': 0.723,
#   'vader_pos': 0.277,
#   'vader_compound': 0.9843,
#   'roberta_neg': 0.0014562994,
#   'roberta_neu': 0.0064995163,
#   'roberta_pos': 0.9920442},
#  652392732: {'vader_neg': 0.0,
#   'vader_neu': 0.85,
#   'vader_pos': 0.15,
#   'vader_compound': 0.7964,
#   'roberta_neg': 0.003825881,
#   'roberta_neu': 0.026425641,
#   'roberta_pos': 0.96974844},
#  652253746: {'vader_neg': 0.1,
#   'vader_neu': 0.674,
#   'vader_pos': 0.226,
#   'vader_compound': 0.9464,
#   'roberta_neg': 0.013712184,
#   'roberta_neu': 0.06229233,
#   'roberta_pos': 0.92399555},
#  652250866: {'vader_neg': 0.0,
#   'vader_neu': 0.755,
#   'vader_pos': 0.245,
#   'vader_compound': 0.8937,
#   'roberta_neg': 0.0019965817,
#   'roberta_neu': 0.005683278,
#   'roberta_pos': 0.9923201},
#  652247613: {'vader_neg': 0.139,
#   'vader_neu': 0.741,
#   'vader_pos': 0.12,
#   'vader_compound': -0.3788,
#   'roberta_neg': 0.77639234,
#   'roberta_neu': 0.16699868,
#   'roberta_pos': 0.056608934},
#  652203379: {'vader_neg': 0.0,
#   'vader_neu': 0.828,
#   'vader_pos': 0.172,
#   'vader_compound': 0.9386,
#   'roberta_neg': 0.0013515272,
#   'roberta_neu': 0.009433592,
#   'roberta_pos': 0.98921484},
#  652127387: {'vader_neg': 0.147,
#   'vader_neu': 0.694,
#   'vader_pos': 0.159,
#   'vader_compound': 0.09,
#   'roberta_neg': 0.77038866,
#   'roberta_neu': 0.18074699,
#   'roberta_pos': 0.048864383},
#  651987801: {'vader_neg': 0.0,
#   'vader_neu': 0.719,
#   'vader_pos': 0.281,
#   'vader_compound': 0.8685,
#   'roberta_neg': 0.0014198093,
#   'roberta_neu': 0.0059152464,
#   'roberta_pos': 0.9926649},
#  651947556: {'vader_neg': 0.027,
#   'vader_neu': 0.8,
#   'vader_pos': 0.173,
#   'vader_compound': 0.9975,
#   'roberta_neg': 0.0023240184,
#   'roberta_neu': 0.021901032,
#   'roberta_pos': 0.9757749},
#  651889664: {'vader_neg': 0.067,
#   'vader_neu': 0.755,
#   'vader_pos': 0.178,
#   'vader_compound': 0.9918,
#   'roberta_neg': 0.12983236,
#   'roberta_neu': 0.323253,
#   'roberta_pos': 0.54691464},
#  651857855: {'vader_neg': 0.153,
#   'vader_neu': 0.765,
#   'vader_pos': 0.082,
#   'vader_compound': -0.8872,
#   'roberta_neg': 0.76477027,
#   'roberta_neu': 0.18076879,
#   'roberta_pos': 0.054460928},
#  651835605: {'vader_neg': 0.03,
#   'vader_neu': 0.73,
#   'vader_pos': 0.24,
#   'vader_compound': 0.9042,
#   'roberta_neg': 0.0020966248,
#   'roberta_neu': 0.012309128,
#   'roberta_pos': 0.9855942},
#  651818469: {'vader_neg': 0.0,
#   'vader_neu': 0.868,
#   'vader_pos': 0.132,
#   'vader_compound': 0.9275,
#   'roberta_neg': 0.0101754125,
#   'roberta_neu': 0.058092766,
#   'roberta_pos': 0.9317318},
#  651604017: {'vader_neg': 0.0,
#   'vader_neu': 0.806,
#   'vader_pos': 0.194,
#   'vader_compound': 0.5859,
#   'roberta_neg': 0.0016947875,
#   'roberta_neu': 0.022508642,
#   'roberta_pos': 0.9757966},
#  651603230: {'vader_neg': 0.0,
#   'vader_neu': 0.788,
#   'vader_pos': 0.212,
#   'vader_compound': 0.7684,
#   'roberta_neg': 0.008938348,
#   'roberta_neu': 0.05336539,
#   'roberta_pos': 0.9376962},
#  651600397: {'vader_neg': 0.0,
#   'vader_neu': 0.725,
#   'vader_pos': 0.275,
#   'vader_compound': 0.9704,
#   'roberta_neg': 0.0014050009,
#   'roberta_neu': 0.00654612,
#   'roberta_pos': 0.9920489},
#  651412296: {'vader_neg': 0.0,
#   'vader_neu': 0.746,
#   'vader_pos': 0.254,
#   'vader_compound': 0.8176,
#   'roberta_neg': 0.0019747787,
#   'roberta_neu': 0.009719265,
#   'roberta_pos': 0.988306},
#  651338485: {'vader_neg': 0.0,
#   'vader_neu': 0.786,
#   'vader_pos': 0.214,
#   'vader_compound': 0.9837,
#   'roberta_neg': 0.004737176,
#   'roberta_neu': 0.035971783,
#   'roberta_pos': 0.95929104},
#  651337366: {'vader_neg': 0.036,
#   'vader_neu': 0.906,
#   'vader_pos': 0.059,
#   'vader_compound': 0.2846,
#   'roberta_neg': 0.4083934,
#   'roberta_neu': 0.40179616,
#   'roberta_pos': 0.18981048},
#  651327634: {'vader_neg': 0.026,
#   'vader_neu': 0.825,
#   'vader_pos': 0.149,
#   'vader_compound': 0.9983,
#   'roberta_neg': 0.0051460816,
#   'roberta_neu': 0.21189538,
#   'roberta_pos': 0.7829585},
#  651308877: {'vader_neg': 0.0,
#   'vader_neu': 0.779,
#   'vader_pos': 0.221,
#   'vader_compound': 0.9407,
#   'roberta_neg': 0.0016832242,
#   'roberta_neu': 0.008866687,
#   'roberta_pos': 0.98945004},
#  651295698: {'vader_neg': 0.017,
#   'vader_neu': 0.633,
#   'vader_pos': 0.35,
#   'vader_compound': 0.9855,
#   'roberta_neg': 0.0020506473,
# ...
#   'vader_neu': 0.74,
#   'vader_pos': 0.26,
#   'vader_compound': 0.8975,
#   'roberta_neg': 0.0012772375,
#   'roberta_neu': 0.0068418956,
#   'roberta_pos': 0.99188083},
#  604125182: {'vader_neg': 0.035,
#   'vader_neu': 0.752,
#   'vader_pos': 0.213,
#   'vader_compound': 0.9707,
#   'roberta_neg': 0.0076068323,
#   'roberta_neu': 0.04719515,
#   'roberta_pos': 0.94519806},
#  604089676: {'vader_neg': 0.21,
#   'vader_neu': 0.746,
#   'vader_pos': 0.043,
#   'vader_compound': -0.8704,
#   'roberta_neg': 0.8457289,
#   'roberta_neu': 0.12210334,
#   'roberta_pos': 0.03216774},
#  604075777: {'vader_neg': 0.113,
#   'vader_neu': 0.714,
#   'vader_pos': 0.172,
#   'vader_compound': 0.34,
#   'roberta_neg': 0.15871947,
#   'roberta_neu': 0.337463,
#   'roberta_pos': 0.50381756},
#  604054681: {'vader_neg': 0.051,
#   'vader_neu': 0.869,
#   'vader_pos': 0.081,
#   'vader_compound': 0.5114,
#   'roberta_neg': 0.006771256,
#   'roberta_neu': 0.058780216,
#   'roberta_pos': 0.93444854},
#  603999795: {'vader_neg': 0.073,
#   'vader_neu': 0.731,
#   'vader_pos': 0.196,
#   'vader_compound': 0.5719,
#   'roberta_neg': 0.035520922,
#   'roberta_neu': 0.17476006,
#   'roberta_pos': 0.78971905},
#  603960206: {'vader_neg': 0.0,
#   'vader_neu': 0.679,
#   'vader_pos': 0.321,
#   'vader_compound': 0.9516,
#   'roberta_neg': 0.0018595232,
#   'roberta_neu': 0.008598312,
#   'roberta_pos': 0.9895421},
#  603914623: {'vader_neg': 0.064,
#   'vader_neu': 0.936,
#   'vader_pos': 0.0,
#   'vader_compound': -0.1655,
#   'roberta_neg': 0.65428585,
#   'roberta_neu': 0.30835655,
#   'roberta_pos': 0.0373576},
#  603903279: {'vader_neg': 0.046,
#   'vader_neu': 0.842,
#   'vader_pos': 0.112,
#   'vader_compound': 0.4767,
#   'roberta_neg': 0.09333178,
#   'roberta_neu': 0.5042628,
#   'roberta_pos': 0.4024055},
#  603749831: {'vader_neg': 0.0,
#   'vader_neu': 0.71,
#   'vader_pos': 0.29,
#   'vader_compound': 0.8689,
#   'roberta_neg': 0.0040645082,
#   'roberta_neu': 0.022365786,
#   'roberta_pos': 0.97356975},
#  603657975: {'vader_neg': 0.039,
#   'vader_neu': 0.796,
#   'vader_pos': 0.164,
#   'vader_compound': 0.991,
#   'roberta_neg': 0.0018380771,
#   'roberta_neu': 0.01637054,
#   'roberta_pos': 0.9817914},
#  603641404: {'vader_neg': 0.0,
#   'vader_neu': 0.932,
#   'vader_pos': 0.068,
#   'vader_compound': 0.8807,
#   'roberta_neg': 0.0033728504,
#   'roberta_neu': 0.062399134,
#   'roberta_pos': 0.934228},
#  603635647: {'vader_neg': 0.022,
#   'vader_neu': 0.852,
#   'vader_pos': 0.126,
#   'vader_compound': 0.9835,
#   'roberta_neg': 0.020598914,
#   'roberta_neu': 0.20239785,
#   'roberta_pos': 0.7770033},
#  603597793: {'vader_neg': 0.0,
#   'vader_neu': 0.875,
#   'vader_pos': 0.125,
#   'vader_compound': 0.7901,
#   'roberta_neg': 0.0012033348,
#   'roberta_neu': 0.009290651,
#   'roberta_pos': 0.98950595},
#  603527492: {'vader_neg': 0.0,
#   'vader_neu': 0.816,
#   'vader_pos': 0.184,
#   'vader_compound': 0.8822,
#   'roberta_neg': 0.0037098343,
#   'roberta_neu': 0.117068276,
#   'roberta_pos': 0.87922186},
#  603396251: {'vader_neg': 0.0,
#   'vader_neu': 0.768,
#   'vader_pos': 0.232,
#   'vader_compound': 0.908,
#   'roberta_neg': 0.0012463972,
#   'roberta_neu': 0.011806532,
#   'roberta_pos': 0.98694706},
#  603395786: {'vader_neg': 0.113,
#   'vader_neu': 0.799,
#   'vader_pos': 0.088,
#   'vader_compound': -0.765,
#   'roberta_neg': 0.25843868,
#   'roberta_neu': 0.40425378,
#   'roberta_pos': 0.33730754},
#  603377174: {'vader_neg': 0.07,
#   'vader_neu': 0.692,
#   'vader_pos': 0.238,
#   'vader_compound': 0.9648,
#   'roberta_neg': 0.003910388,
#   'roberta_neu': 0.031948894,
#   'roberta_pos': 0.9641408},
#  603324824: {'vader_neg': 0.0,
#   'vader_neu': 0.962,
#   'vader_pos': 0.038,
#   'vader_compound': 0.25,
#   'roberta_neg': 0.004564102,
#   'roberta_neu': 0.096352875,
#   'roberta_pos': 0.899083},
#  603275546: {'vader_neg': 0.214,
#   'vader_neu': 0.708,
#   'vader_pos': 0.079,
#   'vader_compound': -0.6056,
#   'roberta_neg': 0.6292913,
#   'roberta_neu': 0.27871913,
#   'roberta_pos': 0.0919896},
#  603259159: {'vader_neg': 0.026,
#   'vader_neu': 0.796,
#   'vader_pos': 0.178,
#   'vader_compound': 0.9183,
#   'roberta_neg': 0.0017213558,
#   'roberta_neu': 0.0279615,
#   'roberta_pos': 0.9703171},
#  603174247: {'vader_neg': 0.108,
#   'vader_neu': 0.715,
#   'vader_pos': 0.177,
#   'vader_compound': 0.7213,
#   'roberta_neg': 0.059710085,
#   'roberta_neu': 0.25948218,
#   'roberta_pos': 0.68080777},
#  603148449: {'vader_neg': 0.054,
#   'vader_neu': 0.844,
#   'vader_pos': 0.102,
#   'vader_compound': 0.9839,
#   'roberta_neg': 0.32946905,
#   'roberta_neu': 0.41352272,
#   'roberta_pos': 0.25700825},
#  603133215: {'vader_neg': 0.0,
#   'vader_neu': 0.746,
#   'vader_pos': 0.254,
#   'vader_compound': 0.9321,
#   'roberta_neg': 0.0034059803,
#   'roberta_neu': 0.021362826,
#   'roberta_pos': 0.9752312},
#  603111669: {'vader_neg': 0.043,
#   'vader_neu': 0.574,
#   'vader_pos': 0.383,
#   'vader_compound': 0.9531,
#   'roberta_neg': 0.0033391644,
#   'roberta_neu': 0.008127192,
#   'roberta_pos': 0.9885337},
#  603074080: {'vader_neg': 0.0,
#   'vader_neu': 0.544,
#   'vader_pos': 0.456,
#   'vader_compound': 0.9795,
#   'roberta_neg': 0.0019820444,
#   'roberta_neu': 0.0057103867,
#   'roberta_pos': 0.99230754},
#  602781281: {'vader_neg': 0.021,
#   'vader_neu': 0.844,
#   'vader_pos': 0.134,
#   'vader_compound': 0.8612,
#   'roberta_neg': 0.0034445587,
#   'roberta_neu': 0.017770479,
#   'roberta_pos': 0.978785},
#  602535588: {'vader_neg': 0.023,
#   'vader_neu': 0.826,
#   'vader_pos': 0.151,
#   'vader_compound': 0.9835,
#   'roberta_neg': 0.0033193172,
#   'roberta_neu': 0.043745216,
#   'roberta_pos': 0.95293546},
#  602489018: {'vader_neg': 0.0,
#   'vader_neu': 0.736,
#   'vader_pos': 0.264,
#   'vader_compound': 0.8012,
#   'roberta_neg': 0.0013652961,
#   'roberta_neu': 0.01549479,
#   'roberta_pos': 0.98313993},
#  602409987: {'vader_neg': 0.033,
#   'vader_neu': 0.796,
#   'vader_pos': 0.171,
#   'vader_compound': 0.9726,
#   'roberta_neg': 0.00293749,
#   'roberta_neu': 0.03167308,
#   'roberta_pos': 0.9653895},
#  602393605: {'vader_neg': 0.0,
#   'vader_neu': 0.851,
#   'vader_pos': 0.149,
#   'vader_compound': 0.6369,
#   'roberta_neg': 0.234184,
#   'roberta_neu': 0.5365502,
#   'roberta_pos': 0.22926576},
#  602389962: {'vader_neg': 0.028,
#   'vader_neu': 0.813,
#   'vader_pos': 0.159,
#   'vader_compound': 0.8971,
#   'roberta_neg': 0.0016807732,
#   'roberta_neu': 0.010030908,
#   'roberta_pos': 0.9882883},
#  602248757: {'vader_neg': 0.017,
#   'vader_neu': 0.776,
#   'vader_pos': 0.207,
#   'vader_compound': 0.9908,
#   'roberta_neg': 0.0049266946,
#   'roberta_neu': 0.04212157,
#   'roberta_pos': 0.9529517},
#  602221005: {'vader_neg': 0.0,
#   'vader_neu': 0.838,
#   'vader_pos': 0.162,
#   'vader_compound': 0.989,
#   'roberta_neg': 0.0018042497,
#   'roberta_neu': 0.035522513,
#   'roberta_pos': 0.9626733},
#  602205941: {'vader_neg': 0.098,
#   'vader_neu': 0.902,
#   'vader_pos': 0.0,
#   'vader_compound': -0.2924,
#   'roberta_neg': 0.034108996,
#   'roberta_neu': 0.1565889,
#   'roberta_pos': 0.8093021},
#  602195085: {'vader_neg': 0.046,
#   'vader_neu': 0.868,
#   'vader_pos': 0.086,
#   'vader_compound': 0.877,
#   'roberta_neg': 0.7502493,
#   'roberta_neu': 0.20170557,
#   'roberta_pos': 0.048045076},
#  602155646: {'vader_neg': 0.0,
#   'vader_neu': 0.854,
#   'vader_pos': 0.146,
#   'vader_compound': 0.9058,
#   'roberta_neg': 0.001920078,
#   'roberta_neu': 0.012183447,
#   'roberta_pos': 0.9858965},
#  602135489: {'vader_neg': 0.0,
#   'vader_neu': 0.612,
#   'vader_pos': 0.388,
#   'vader_compound': 0.9551,
#   'roberta_neg': 0.0010952151,
#   'roberta_neu': 0.00734768,
#   'roberta_pos': 0.9915571},
#  601864148: {'vader_neg': 0.025,
#   'vader_neu': 0.797,
#   'vader_pos': 0.178,
#   'vader_compound': 0.9872,
#   'roberta_neg': 0.010233275,
#   'roberta_neu': 0.045393277,
#   'roberta_pos': 0.9443735},
#  601653975: {'vader_neg': 0.156,
#   'vader_neu': 0.677,
#   'vader_pos': 0.167,
#   'vader_compound': -0.09,
#   'roberta_neg': 0.04366148,
#   'roberta_neu': 0.14556564,
#   'roberta_pos': 0.8107729},
#  601650226: {'vader_neg': 0.177,
#   'vader_neu': 0.737,
#   'vader_pos': 0.086,
#   'vader_compound': -0.7796,
#   'roberta_neg': 0.74376214,
#   'roberta_neu': 0.19717424,
#   'roberta_pos': 0.05906366},
#  601556535: {'vader_neg': 0.017,
#   'vader_neu': 0.803,
#   'vader_pos': 0.181,
#   'vader_compound': 0.9677,
#   'roberta_neg': 0.0018493504,
#   'roberta_neu': 0.016598172,
#   'roberta_pos': 0.98155254},
#  601501440: {'vader_neg': 0.054,
#   'vader_neu': 0.707,
#   'vader_pos': 0.239,
#   'vader_compound': 0.9095,
#   'roberta_neg': 0.001685622,
#   'roberta_neu': 0.0076589445,
#   'roberta_pos': 0.9906555},
#  601330488: {'vader_neg': 0.038,
#   'vader_neu': 0.646,
#   'vader_pos': 0.316,
#   'vader_compound': 0.993,
#   'roberta_neg': 0.012401709,
#   'roberta_neu': 0.043473475,
#   'roberta_pos': 0.9441249},
#  601328919: {'vader_neg': 0.0,
#   'vader_neu': 0.683,
#   'vader_pos': 0.317,
#   'vader_compound': 0.8508,
#   'roberta_neg': 0.0012580035,
#   'roberta_neu': 0.007119134,
#   'roberta_pos': 0.99162287},
#  601297871: {'vader_neg': 0.0,
#   'vader_neu': 0.876,
#   'vader_pos': 0.124,
#   'vader_compound': 0.6413,
#   'roberta_neg': 0.022439934,
#   'roberta_neu': 0.100720026,
#   'roberta_pos': 0.87684005},
#  601216627: {'vader_neg': 0.1,
#   'vader_neu': 0.682,
#   'vader_pos': 0.218,
#   'vader_compound': 0.5019,
#   'roberta_neg': 0.033372335,
#   'roberta_neu': 0.11754808,
#   'roberta_pos': 0.84907955},
#  601164666: {'vader_neg': 0.0,
#   'vader_neu': 0.544,
#   'vader_pos': 0.456,
#   'vader_compound': 0.8979,
#   'roberta_neg': 0.002276304,
#   'roberta_neu': 0.014695543,
#   'roberta_pos': 0.9830282},
#  600676840: {'vader_neg': 0.025,
#   'vader_neu': 0.903,
#   'vader_pos': 0.073,
#   'vader_compound': 0.5719,
#   'roberta_neg': 0.015691109,
#   'roberta_neu': 0.13647266,
#   'roberta_pos': 0.84783626},
#  600669367: {'vader_neg': 0.077,
#   'vader_neu': 0.715,
#   'vader_pos': 0.208,
#   'vader_compound': 0.9605,
#   'roberta_neg': 0.0021113746,
#   'roberta_neu': 0.02551083,
#   'roberta_pos': 0.9723778},
#  600662323: {'vader_neg': 0.064,
#   'vader_neu': 0.789,
#   'vader_pos': 0.147,
#   'vader_compound': 0.8593,
#   'roberta_neg': 0.09476863,
#   'roberta_neu': 0.20800082,
#   'roberta_pos': 0.6972305},
#  600579861: {'vader_neg': 0.022,
#   'vader_neu': 0.873,
#   'vader_pos': 0.105,
#   'vader_compound': 0.6055,
#   'roberta_neg': 0.01421996,
#   'roberta_neu': 0.10075678,
#   'roberta_pos': 0.88502324},
#  600577640: {'vader_neg': 0.0,
#   'vader_neu': 0.75,
#   'vader_pos': 0.25,
#   'vader_compound': 0.9328,
#   'roberta_neg': 0.0014876928,
#   'roberta_neu': 0.00735578,
#   'roberta_pos': 0.9911566},
#  600566005: {'vader_neg': 0.154,
#   'vader_neu': 0.676,
#   'vader_pos': 0.17,
#   'vader_compound': 0.5113,
#   'roberta_neg': 0.02435761,
#   'roberta_neu': 0.10160483,
#   'roberta_pos': 0.87403756},
#  600475703: {'vader_neg': 0.032,
#   'vader_neu': 0.853,
#   'vader_pos': 0.115,
#   'vader_compound': 0.81,
#   'roberta_neg': 0.0066681313,
#   'roberta_neu': 0.056429345,
#   'roberta_pos': 0.93690246},
#  600321349: {'vader_neg': 0.0,
#   'vader_neu': 0.597,
#   'vader_pos': 0.403,
#   'vader_compound': 0.9307,
#   'roberta_neg': 0.0018539504,
#   'roberta_neu': 0.009280881,
#   'roberta_pos': 0.98886514},
#  600303198: {'vader_neg': 0.101,
#   'vader_neu': 0.836,
#   'vader_pos': 0.062,
#   'vader_compound': -0.9396,
#   'roberta_neg': 0.77586037,
#   'roberta_neu': 0.19422217,
#   'roberta_pos': 0.029917367},
#  600295156: {'vader_neg': 0.0,
#   'vader_neu': 1.0,
#   'vader_pos': 0.0,
#   'vader_compound': 0.0,
#   'roberta_neg': 0.001189024,
#   'roberta_neu': 0.027851379,
#   'roberta_pos': 0.97095954},
#  600278676: {'vader_neg': 0.042,
#   'vader_neu': 0.794,
#   'vader_pos': 0.164,
#   'vader_compound': 0.9594,
#   'roberta_neg': 0.004412231,
#   'roberta_neu': 0.025200084,
#   'roberta_pos': 0.97038776},
#  600240918: {'vader_neg': 0.031,
#   'vader_neu': 0.817,
#   'vader_pos': 0.152,
#   'vader_compound': 0.8225,
#   'roberta_neg': 0.0018808374,
#   'roberta_neu': 0.020471407,
#   'roberta_pos': 0.9776478},
#  600164076: {'vader_neg': 0.031,
#   'vader_neu': 0.856,
#   'vader_pos': 0.113,
#   'vader_compound': 0.9874,
#   'roberta_neg': 0.124874994,
#   'roberta_neu': 0.3521129,
#   'roberta_pos': 0.5230121},
#  600063796: {'vader_neg': 0.058,
#   'vader_neu': 0.785,
#   'vader_pos': 0.157,
#   'vader_compound': 0.9834,
#   'roberta_neg': 0.053620428,
#   'roberta_neu': 0.13416378,
#   'roberta_pos': 0.81221575},
#  600023714: {'vader_neg': 0.0,
#   'vader_neu': 0.627,
#   'vader_pos': 0.373,
#   'vader_compound': 0.94,
#   'roberta_neg': 0.002229091,
#   'roberta_neu': 0.0051140706,
#   'roberta_pos': 0.99265677},
#  599979789: {'vader_neg': 0.0,
#   'vader_neu': 0.802,
#   'vader_pos': 0.198,
#   'vader_compound': 0.9805,
#   'roberta_neg': 0.012580478,
#   'roberta_neu': 0.123802714,
#   'roberta_pos': 0.8636168},
#  599892429: {'vader_neg': 0.022,
#   'vader_neu': 0.861,
#   'vader_pos': 0.117,
#   'vader_compound': 0.9048,
#   'roberta_neg': 0.033199,
#   'roberta_neu': 0.12023787,
#   'roberta_pos': 0.84656316},
#  599880350: {'vader_neg': 0.021,
#   'vader_neu': 0.82,
#   'vader_pos': 0.158,
#   'vader_compound': 0.9183,
#   'roberta_neg': 0.06036251,
#   'roberta_neu': 0.20358889,
#   'roberta_pos': 0.7360486},
#  599880269: {'vader_neg': 0.057,
#   'vader_neu': 0.943,
#   'vader_pos': 0.0,
#   'vader_compound': -0.6124,
#   'roberta_neg': 0.10247556,
#   'roberta_neu': 0.36662638,
#   'roberta_pos': 0.53089803},
#  599750378: {'vader_neg': 0.048,
#   'vader_neu': 0.825,
#   'vader_pos': 0.127,
#   'vader_compound': 0.8857,
#   'roberta_neg': 0.36920998,
#   'roberta_neu': 0.4473317,
#   'roberta_pos': 0.18345836},
#  599739026: {'vader_neg': 0.012,
#   'vader_neu': 0.804,
#   'vader_pos': 0.183,
#   'vader_compound': 0.9601,
#   'roberta_neg': 0.0017840738,
#   'roberta_neu': 0.013941421,
#   'roberta_pos': 0.98427445},
#  599710773: {'vader_neg': 0.045,
#   'vader_neu': 0.873,
#   'vader_pos': 0.082,
#   'vader_compound': 0.9013,
#   'roberta_neg': 0.54603755,
#   'roberta_neu': 0.32303926,
#   'roberta_pos': 0.13092309},
#  599686738: {'vader_neg': 0.0,
#   'vader_neu': 0.491,
#   'vader_pos': 0.509,
#   'vader_compound': 0.926,
#   'roberta_neg': 0.0013968863,
#   'roberta_neu': 0.007610604,
#   'roberta_pos': 0.99099255},
#  599648203: {'vader_neg': 0.049,
#   'vader_neu': 0.751,
#   'vader_pos': 0.2,
#   'vader_compound': 0.9953,
#   'roberta_neg': 0.045179505,
#   'roberta_neu': 0.14453182,
#   'roberta_pos': 0.81028867},
#  599608004: {'vader_neg': 0.0,
#   'vader_neu': 0.735,
#   'vader_pos': 0.265,
#   'vader_compound': 0.8955,
#   'roberta_neg': 0.001630048,
#   'roberta_neu': 0.016114201,
#   'roberta_pos': 0.9822558},
#  599600814: {'vader_neg': 0.045,
#   'vader_neu': 0.435,
#   'vader_pos': 0.521,
#   'vader_compound': 0.9706,
#   'roberta_neg': 0.0020021978,
#   'roberta_neu': 0.0065832073,
#   'roberta_pos': 0.9914146},
#  599569077: {'vader_neg': 0.0,
#   'vader_neu': 0.869,
#   'vader_pos': 0.131,
#   'vader_compound': 0.9524,
#   'roberta_neg': 0.0049226373,
#   'roberta_neu': 0.06790457,
#   'roberta_pos': 0.9271728},
#  599441164: {'vader_neg': 0.0,
#   'vader_neu': 0.799,
#   'vader_pos': 0.201,
#   'vader_compound': 0.9267,
#   'roberta_neg': 0.002319617,
#   'roberta_neu': 0.040063288,
#   'roberta_pos': 0.9576171},
#  599437943: {'vader_neg': 0.0,
#   'vader_neu': 0.782,
#   'vader_pos': 0.218,
#   'vader_compound': 0.9779,
#   'roberta_neg': 0.003667069,
#   'roberta_neu': 0.006784003,
#   'roberta_pos': 0.9895489},
#  599422690: {'vader_neg': 0.0,
#   'vader_neu': 0.759,
#   'vader_pos': 0.241,
#   'vader_compound': 0.9762,
#   'roberta_neg': 0.0024709029,
#   'roberta_neu': 0.025780944,
#   'roberta_pos': 0.9717481},
#  599417131: {'vader_neg': 0.099,
#   'vader_neu': 0.822,
#   'vader_pos': 0.079,
#   'vader_compound': -0.3489,
#   'roberta_neg': 0.02460539,
#   'roberta_neu': 0.057480954,
#   'roberta_pos': 0.9179136},
#  599411563: {'vader_neg': 0.046,
#   'vader_neu': 0.819,
#   'vader_pos': 0.135,
#   'vader_compound': 0.4582,
#   'roberta_neg': 0.003451064,
#   'roberta_neu': 0.022084258,
#   'roberta_pos': 0.97446465},
#  599318254: {'vader_neg': 0.0,
#   'vader_neu': 0.813,
#   'vader_pos': 0.187,
#   'vader_compound': 0.9577,
#   'roberta_neg': 0.001117423,
#   'roberta_neu': 0.009204522,
#   'roberta_pos': 0.989678},
#  599310213: {'vader_neg': 0.02,
#   'vader_neu': 0.835,
#   'vader_pos': 0.145,
#   'vader_compound': 0.9908,
#   'roberta_neg': 0.035449985,
#   'roberta_neu': 0.13075252,
#   'roberta_pos': 0.83379745},
#  599236174: {'vader_neg': 0.0,
#   'vader_neu': 0.506,
#   'vader_pos': 0.494,
#   'vader_compound': 0.8932,
#   'roberta_neg': 0.0012059134,
#   'roberta_neu': 0.019227505,
#   'roberta_pos': 0.97956663},
#  ...}

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'Review_ID'})
results_df = results_df.merge(df, how='left')
#merging the results into a dataframe

# %%
results_df.head(3) #check that the merge worked, it did
# Out:
#    Review_ID  vader_neg  vader_neu  vader_pos  vader_compound  roberta_neg  \
# 0  670801367      0.000      0.754      0.246          0.9008     0.001560
# 1  670760708      0.000      0.741      0.259          0.9595     0.001603
# 2  670565072      0.087      0.729      0.184          0.7319     0.009501
#
#    roberta_neu  roberta_pos  Rating  \
# 0     0.009007     0.989433       5
# 1     0.010468     0.987929       5
# 2     0.053588     0.936911       4
#
#                                          Review_Text                 Branch
# 0  This place has always been and forever will be...  Disneyland_California
# 1  A great day of simple fun and thrills. Bring c...  Disneyland_California
# 2  All and all a great day was had. The crowds ar...  Disneyland_California

# %% [markdown]
# # VADER vs RoBERTa Comparison

# %%
results_df.columns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
sns.pairplot(data=results_df, 
             vars = ['vader_neg', 'vader_neu', 'vader_pos',
                    'roberta_neg', 'roberta_neu', 'roberta_pos'],
            hue='Rating',
            palette='tab10')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# What are the graphs telling us?
# - Observing the bell curves shows a tighter (leptokurtic) middle point on the RoBERTa model. This means that the model is more confident in clustering pos/neu/neg review sentiments based on their text. In comparison, the VADERS model shows a far wider (platykurtic) bell curve, which highlights a wider variance in the scores assigned to sentiment.
# - The scatterplots are harder to interpret because it's a lot of data being squeezed into a smaller space. But it shows that there is a wider variance in how scores are assigned. Looking at neg and positive, where we should see more clustering of 1s and 5s, the VADERS model is not as tight compared to the RoBERTa model.
# - Overall, through eyeballing these charts, I can say that both the VADERS and RoBERTa model have an easier time classifying positive sentiment than negative sentiment - as observed by more purples (5s) being near the top of the chart in negative attributions compared to blues (1s) in the positive attributions.

# %% [markdown]
# ## Visualise Sentiment Breakdown for Each Model

# %%
# categorise VADER sentiments based on compound score
results_df['vader_sentiment'] = results_df['vader_compound'].apply(lambda x: 'positive' if x > 0.05 else ('negative' if x < -0.05 else 'neutral'))

# categorise roBERTa sentiments based on scores
results_df['roberta_sentiment'] = results_df.apply(lambda x: 'positive' if x['roberta_pos'] > x['roberta_neg'] and x['roberta_pos'] > x['roberta_neu'] else ('negative' if x['roberta_neg'] > x['roberta_pos'] and x['roberta_neg'] > x['roberta_neu'] else 'neutral'), axis=1)

# percentages for VADER sentiments
vader_counts = results_df['vader_sentiment'].value_counts(normalize=True) * 100

# percentages for roBERTa sentiments
roberta_counts = results_df['roberta_sentiment'].value_counts(normalize=True) * 100

# plot VADER pie chart
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
vader_counts.plot.pie(autopct='%1.1f%%', colors=sns.color_palette("pastel"))
plt.title('VADER Sentiment Distribution')
plt.ylabel('')

# plot roBERTa pie chart
plt.subplot(1, 3, 2)
roberta_counts.plot.pie(autopct='%1.1f%%', colors=sns.color_palette("pastel"))
plt.title('roBERTa Sentiment Distribution')
plt.ylabel('')

rating_counts = results_df['Rating'].value_counts(normalize=True) * 100

# Plotting the ratings pie chart
plt.subplot(1, 3, 3)
rating_counts.plot.pie(autopct='%1.1f%%', colors=sns.color_palette("pastel"), startangle=90, fontsize=7)
plt.title('Ratings Distribution')
plt.ylabel('')

#show the pie charts
plt.tight_layout()
plt.show()

# %% [markdown]
# Fairly similar distributions for both models. Obviously, because roBERTa uses the stronger technology, it's probably more accurate.
#
# The best way to compare their accuracy will be agains the ratings given (out of 5).
#
# Let's say that positive will equal a 4 or 5 rating. Neutral will be a 3 rating. And 1 or 2 is a negative rating.
#
# The most accurate model will have similar % distribution according to those numbers. And that seems to be the roBERTa model.
#
# Intereting points to note:
# - both have underestimated the neutral sentiment based on ratings given; VADER moreso
# - Both have overestimated the negative; roBERTa moreso
# - VADER overestimated positive
#
# Overall, it seems like VADER is much more sensitive to positive attributions, and seems to prefer to avoid neutral sentiment. This may be due to not looking at context. However, even roBERTa has underestimated neutral in favour of the negative. There's probably some nauance here. People can write long reviews, and it's difficult to give a precise overview of, let'say, a 300 word review where someone has expressed 3 - 4 sentiments across a number of themes. Something like Disneyworld has many parts - the rides, food, atmosphere, weather, locations, other guests, views, attractions, mascots, ticket prices, wait times, etc... Giving a single score to review which could look at these themes in different ways is not great.
#
# The value seems to be drilling into the data, say, pulling up a negative (1/2) rating, with a neutral or positive sentiment, and seeing what they're saying.

# %% [markdown]
# # Phrase Count by Sentiment
#
# The idea is now to get major topics by sentiment.
#
# These are the criteria:
# - roberta_pos > .5 AND rating > 3
# - roberta_neg > .5 AND rating < 3
#
# The idea is to create two dataframes, one holding the positive sentiments, one with negatives.
#
# Each of these dataframes will then have topics (~ 3 words) extracted, and these topics will have a summary next to them (~ 120 words)
#
# Then create a topic network visual for those topics using networkx.

# %% [markdown]
# ### Remove Irrelevant Columns and Remove Stopwords

# %%
import spacy
from collections import Counter
import string

# %%
#spacy.cli.download("en_core_web_lg")
nlp = spacy.load("en_core_web_lg")

# %%
neg_reviews = results_df[(results_df['roberta_neg'] > 0.5) & (results_df['Rating'] < 3)]
pos_reviews = results_df[(results_df['roberta_pos'] > 0.5) & (results_df['Rating'] > 3)]

neg_reviews.drop(['Review_ID', 'vader_neg', 
                           'vader_neu', 'vader_pos', 'vader_compound', 
                           'roberta_neg', 'roberta_neu', 'roberta_pos', 'Rating', 'Branch',
                 'vader_sentiment', 'roberta_sentiment'], axis=1)
pos_reviews.drop(['Review_ID', 'vader_neg', 
                           'vader_neu', 'vader_pos', 'vader_compound', 
                           'roberta_neg', 'roberta_neu', 'roberta_pos', 'Rating', 'Branch', 
                  'vader_sentiment', 'roberta_sentiment'], axis=1)
# Out:
#                                              Review_Text
# 0      This place has always been and forever will be...
# 1      A great day of simple fun and thrills. Bring c...
# 2      All and all a great day was had. The crowds ar...
# 3      Having been to the Florida location numerous t...
# 4      Had the 4 day pass, spent 3 at DL and one at C...
# ...                                                  ...
# 19400  We were at Disneyland September 8 12th. What a...
# 19401  I have taken my music groups to Disneyland for...
# 19402  This is definitely the Happiest Place on Earth...
# 19404  We take a long weekend trip to California each...
# 19405  Disnyeland has to be the BEST place to take a ...
#
# [15136 rows x 1 columns]

# %%
def remove_stopwords(text):
    doc = nlp(text)
    tokens = [token.text for token in doc if not token.is_stop and not token.is_punct and len(token.text) > 2 and not token.is_space]
    return ' '.join(tokens)

# %%
neg_reviews = neg_reviews[["Review_Text"]].astype(str)
pos_reviews = pos_reviews[["Review_Text"]].astype(str)

# %%
pos_reviews['Review_Text'] = pos_reviews['Review_Text'].apply(remove_stopwords)
neg_reviews['Review_Text'] = neg_reviews['Review_Text'].apply(remove_stopwords)

# %% [markdown]
# ### Parse, Tokenize, and Lemmatize

# %%
def process_column(data, col_to_parse):
    tokens = []
    lemma = []
    pos = []
    parsed_doc = []
    
    for doc in nlp.pipe(data[col_to_parse].astype('unicode').values, batch_size=50):
        if doc.has_annotation:
            parsed_doc.append(doc)
            tokens.append([n.text for n in doc])
            lemma.append([n.text for n in doc])
            pos.append([n.text for n in doc])
        else:
            tokens.append(None)
            lemma.append(None)
            pos.append(None)
        
    return parsed_doc, tokens, lemma, pos

# %%
pos_reviews['parsed'], pos_reviews['tokens'], pos_reviews['lemma'], pos_reviews['posn'] = process_column(pos_reviews, 'Review_Text')
neg_reviews['parsed'], neg_reviews['tokens'], neg_reviews['lemma'], neg_reviews['posn'] = process_column(neg_reviews, 'Review_Text')

# %%
pos_reviews.head(2) #check to make sure it was done
# Out:
#                                          Review_Text  \
# 0  place forever special feeling entering park se...
# 1  great day simple fun thrills Bring cash cheap ...
#
#                                               parsed  \
# 0  (place, forever, special, feeling, entering, p...
# 1  (great, day, simple, fun, thrills, Bring, cash...
#
#                                               tokens  \
# 0  [place, forever, special, feeling, entering, p...
# 1  [great, day, simple, fun, thrills, Bring, cash...
#
#                                                lemma  \
# 0  [place, forever, special, feeling, entering, p...
# 1  [great, day, simple, fun, thrills, Bring, cash...
#
#                                                 posn
# 0  [place, forever, special, feeling, entering, p...
# 1  [great, day, simple, fun, thrills, Bring, cash...

# %% [markdown]
# ## Word Counter

# %%
def count_keywords(lemma_list):
    words = [lemma for sublist in lemma_list for lemma in sublist if lemma]
    word_freq = Counter(words)
    return word_freq

pos_keywords = count_keywords(pos_reviews['lemma'])
neg_keywords = count_keywords(neg_reviews['lemma'])

# %%
pos_keywords.most_common(20)
# Out:
# [('Disneyland', 12662),
#  ('park', 11927),
#  ('time', 10471),
#  ('rides', 10047),
#  ('Disney', 8852),
#  ('day', 8705),
#  ('great', 5965),
#  ('ride', 5679),
#  ('place', 4683),
#  ('fun', 4091),
#  ('kids', 3887),
#  ('visit', 3615),
#  ('wait', 3474),
#  ('like', 3461),
#  ('pass', 3411),
#  ('California', 3238),
#  ('lines', 3200),
#  ('times', 3167),
#  ('days', 3050),
#  ('fast', 3006)]

# %%
neg_keywords.most_common(20)
# Out:
# [('park', 1090),
#  ('rides', 779),
#  ('Disneyland', 758),
#  ('Disney', 756),
#  ('day', 631),
#  ('people', 609),
#  ('time', 555),
#  ('ride', 514),
#  ('line', 486),
#  ('wait', 380),
#  ('place', 350),
#  ('like', 315),
#  ('money', 313),
#  ('lines', 313),
#  ('long', 291),
#  ('kids', 282),
#  ('pass', 264),
#  ('minutes', 259),
#  ('times', 255),
#  ('hours', 255)]

# %% [markdown]
# So this is very basic for now, but we can already see some themes by connecting the dots of the most commonly mentioned (lemmatized) words.
#
# Let's visualise it for business use. Note: max_words should correspond to the words used in the most common earlier so that you're visualising that list. And relative_scaling = 1 will make sure the word size corresponds exactly to the proportion of its occurence in the list.

# %%
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(width=800, height=400, max_words = 20, relative_scaling = 1,
                      background_color='white', colormap = 'GnBu').generate_from_frequencies(pos_keywords)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Positive Sentiment Top 20 Words', fontsize = 40)
plt.show()

# %%
wordcloud = WordCloud(width=800, height=400, max_words = 20, relative_scaling = 1,
                      background_color='white', colormap = 'Reds').generate_from_frequencies(neg_keywords)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Negative Sentiment Top 20 Words', fontsize = 40)
plt.show()

# %% [markdown]
# ## Phrase Counting

# %%
from spacy.matcher import Matcher

# %%
matcher = Matcher(nlp.vocab)
noun_verb_pattern = [{'POS':'NOUN'}, {'POS':'VERB'}]
noun_verb_noun_pattern = [{'POS':'NOUN'}, {'POS':'VERB'}, {'POS':'NOUN'}]
noun_verb_adj_pattern = [{'POS':'NOUN'}, {'POS':'VERB'}, {'POS':'ADJ'}]
adj_noun_pattern = [{'POS':'ADJ'}, {'POS':'NOUN'}]
verb_adj_noun_pattern = [{'POS': 'VERB'}, {'POS': 'ADJ'}, {'POS': 'NOUN'}]
noun_clause_pattern = [{'POS': 'NOUN'}, {'ENT_TYPE': 'RELCL'}]
verb_object_pattern = [{'POS': 'VERB'}, {'DEP': 'dobj'}]
noun_prep_noun_pattern = [{'POS': 'NOUN'}, {'POS': 'ADP'}, {'POS': 'NOUN'}]
verb_noun_noun_pattern = [{'POS':'VERB'}, {'POS':'NOUN'}, {'POS':'NOUN'}]
adj_noun_verb_pattern = [{'POS':'ADJ'}, {'POS':'NOUN'}, {'POS':'VERB'}]

matcher.add("NOUN_VERB", [noun_verb_pattern])
matcher.add("NOUN_VERB_NOUN", [noun_verb_noun_pattern])
matcher.add("NOUN_VERB_ADJ", [noun_verb_adj_pattern])
matcher.add("ADJ_NOUN", [adj_noun_pattern])
matcher.add("VERB_ADJ_NOUN", [verb_adj_noun_pattern])
matcher.add("NOUN_CLAUSE", [noun_clause_pattern])
matcher.add("VERB_OBJECT", [verb_object_pattern])
matcher.add("NOUN_PREP_NOUN", [noun_prep_noun_pattern])
matcher.add("VERB_NOUN_NOUN", [verb_noun_noun_pattern])
matcher.add("ADJ_NOUN_VERB", [adj_noun_verb_pattern])

# %%
def extract_phrases(text):
    doc = nlp(text)
    matches = matcher(doc, as_spans=True)
    phrases = [span.text.lower() for span in matches]
    return phrases

def process_columns(data, col_to_parse):
    all_phrases = []
    for text in data[col_to_parse].dropna().astype('unicode').values:
        phrases = extract_phrases(text)
        all_phrases.extend(phrases)
    return Counter(all_phrases)

# %%
pos_phrase_freq = process_columns(pos_reviews, 'Review_Text')
neg_phrase_freq = process_columns(neg_reviews, 'Review_Text')

# %%
print("Most common phrases in positive reviews:")
print(pos_phrase_freq.most_common(20))

# Print most common phrases for negative reviews
print("\nMost common phrases in negative reviews:")
print(neg_phrase_freq.most_common(20))
# Out:
# Most common phrases in positive reviews:
# [('great time', 1239), ('fast pass', 977), ('happiest place', 849), ('fast passes', 719), ('long lines', 583), ('popular rides', 456), ('great place', 362), ('magical place', 350), ('good time', 303), ('great day', 259), ('wonderful time', 254), ('single rider', 249), ('best time', 238), ('day pass', 223), ('small world', 218), ('little ones', 217), ('great experience', 200), ('spent days', 184), ('early morning', 182), ('cast members', 175)]
#
# Most common phrases in negative reviews:
# [('fast pass', 79), ('happiest place', 76), ('long lines', 60), ('rides closed', 58), ('fast passes', 37), ('lines rides', 32), ('park crowded', 24), ('attractions closed', 22), ('annual pass', 22), ('cast members', 21), ('minutes ride', 20), ('small children', 19), ('half hour', 18), ('long line', 18), ('long time', 18), ('day went', 17), ('good time', 17), ('spend money', 16), ('worth money', 15), ('rides broken', 15)]

# %%
top_pos_phrases = [phrase[0] for phrase in pos_phrase_freq.most_common(20)]
top_neg_phrases = [phrase[0] for phrase in neg_phrase_freq.most_common(20)]

# Creating a DataFrame to store the top phrases
top_phrases_df = pd.DataFrame({
    'Top 20 POSITIVE Phrases': top_pos_phrases,
    'Top 20 NEGATIVE Phrases': top_neg_phrases
})

top_phrases_df
# Out:
#    Top 20 POSITIVE Phrases Top 20 NEGATIVE Phrases
# 0               great time               fast pass
# 1                fast pass          happiest place
# 2           happiest place              long lines
# 3              fast passes            rides closed
# 4               long lines             fast passes
# 5            popular rides             lines rides
# 6              great place            park crowded
# 7            magical place      attractions closed
# 8                good time             annual pass
# 9                great day            cast members
# 10          wonderful time            minutes ride
# 11            single rider          small children
# 12               best time               half hour
# 13                day pass               long line
# 14             small world               long time
# 15             little ones                day went
# 16        great experience               good time
# 17              spent days             spend money
# 18           early morning             worth money
# 19            cast members            rides broken

# %% [markdown]
# A list definitely helps, but let's also visualise these top phrases with similar word clouds.

# %%
wordcloud = WordCloud(width=800, height=400, max_words = 20, relative_scaling = 1,
                      background_color='white', colormap = 'GnBu').generate_from_frequencies(pos_phrase_freq)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Positive Sentiment Top 20 Phrases', fontsize = 40)
plt.show()

# %%
wordcloud = WordCloud(width=800, height=400, max_words = 20, relative_scaling = 1,
                      background_color='white', colormap = 'Reds').generate_from_frequencies(neg_phrase_freq)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Negative Sentiment Top 20 Phrases', fontsize = 40)
plt.show()

# %% [markdown]
# # Topic Modelling with BERTopic & NetworkX

# %%
from pyvis.network import Network as net
from sklearn.metrics.pairwise import cosine_similarity
from bertopic import BERTopic
from bertopic.representation import MaximalMarginalRelevance
from sklearn.feature_extraction.text import CountVectorizer
import networkx as nx
from sentence_transformers import SentenceTransformer

# %%
tokens_pos = [token for doc in pos_reviews['parsed'] for token in doc if not token.is_stop and not token.is_punct]
tokens_neg = [token for doc in neg_reviews['parsed'] for token in doc if not token.is_stop and not token.is_punct]
unique_tokens_pos = list(set(tokens_pos))
unique_tokens_neg = list(set(tokens_neg))

# %%
pos_texts = pos_reviews['parsed'].astype(str).tolist()
neg_texts = neg_reviews['parsed'].astype(str).tolist()

# %%
vectorizer_model = CountVectorizer(ngram_range=(1, 3), stop_words ='english')
sentence_model = SentenceTransformer("all-MiniLM-L6-v2")
representation_model = MaximalMarginalRelevance(diversity=0.30)

model_pos = BERTopic(
    representation_model=representation_model, vectorizer_model=vectorizer_model,
    embedding_model=sentence_model,
    language = 'english', calculate_probabilities=True, verbose = True, 
    min_topic_size = 8, nr_topics="auto", top_n_words=5)

topics_pos, probs_pos = model_pos.fit_transform(pos_texts)

model_neg = BERTopic(
    representation_model=representation_model, vectorizer_model=vectorizer_model,
    embedding_model=sentence_model,
    language = 'english', calculate_probabilities=True, verbose = True, 
    min_topic_size = 8, nr_topics="auto", top_n_words=5)

topics_neg, probs_neg = model_neg.fit_transform(neg_texts)
# Out:
# 2024-07-04 18:22:17,913 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/473 [00:00<?, ?it/s]
# 2024-07-04 18:23:11,012 - BERTopic - Embedding - Completed ✓
# 2024-07-04 18:23:11,013 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-07-04 18:23:16,615 - BERTopic - Dimensionality - Completed ✓
# 2024-07-04 18:23:16,616 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-07-04 18:23:23,654 - BERTopic - Cluster - Completed ✓
# 2024-07-04 18:23:23,654 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-07-04 18:23:29,308 - BERTopic - Representation - Completed ✓
# 2024-07-04 18:23:29,315 - BERTopic - Topic reduction - Reducing number of topics
# 2024-07-04 18:23:33,551 - BERTopic - Topic reduction - Reduced number of topics from 130 to 58
# 2024-07-04 18:23:33,994 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/27 [00:00<?, ?it/s]
# 2024-07-04 18:23:38,987 - BERTopic - Embedding - Completed ✓
# 2024-07-04 18:23:38,988 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-07-04 18:23:40,730 - BERTopic - Dimensionality - Completed ✓
# 2024-07-04 18:23:40,731 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-07-04 18:23:40,765 - BERTopic - Cluster - Completed ✓
# 2024-07-04 18:23:40,765 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-07-04 18:23:41,530 - BERTopic - Representation - Completed ✓
# 2024-07-04 18:23:41,531 - BERTopic - Topic reduction - Reducing number of topics
# 2024-07-04 18:23:41,981 - BERTopic - Topic reduction - Reduced number of topics from 20 to 14

# %%
model_pos.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   9776                       -1_park_disneyland_rides_day
# 1       0   3417               0_disneyland_disney_rides_california
# 2       1    190                        1_place_family_year_magical
# 3       2    148        2_fireworks_parade_parade fireworks_parades
# 4       3    134  3_christmas_disneyland_disneyland christmas_ho...
# 5       4    113                4_expensive_disneyland_disney_money
# 6       5     89        5_birthday_60th_60th anniversary_disneyland
# 7       6     68  6_annual pass_annual passes_times year_season ...
# 8       7     64                    7_characters_rides_place_family
# 9       8     63  8_halloween party_mickey halloween_mickey hall...
# 10      9     58            9_staff_place_cleanliness_staff amazing
# 11     10     54  10_california adventure_cars land_disneyland_r...
# 12     11     50     11_wheelchair_disability_scooter_special needs
# 13     12     48  12_christmas_christmas decorations_holiday dec...
# 14     13     46  13_cast members_disneyland_cast members friend...
# 15     14     45  14_park clean staff_disneyland park clean_staf...
# 16     15     37  15_mansion_haunted mansion_nightmare christmas...
# 17     16     37  16_halloween_halloween party_park halloween_de...
# 18     17     35  17_pirates_pirates caribbean_pirates carribean...
# 19     18     34  18_place earth_kidsbest place earth_earth kids...
# 20     19     32             19_crowds_crowded_weather_crowds great
# 21     20     32       20_blue_food_blue bayou_california adventure
# 22     21     31               21_rides_ages_theme park_family park
# 23     22     30  22_turkey leg_turkey legs_giant turkey leg_gia...
# 24     23     28                    23_rides_lines_visit_rides hour
# 25     24     27   24_star wars_jedi_star wars land_chewbacca darth
# 26     25     22  25_cast members_cast members friendly_members ...
# 27     26     22  26_mickey minnie_parade_world mickey_micky minnie
# 28     27     22                  27_park_day food_leap_clean staff
# 29     28     21  28_fast pass_hopper pass_park hopper pass_fast...
# 30     29     20         29_mickey_minnie mickey_mickey donald_kids
# 31     30     19  30_indiana jones ride_loved indiana jones_love...
# 32     31     18  31_attractions closed_rides closed_ride closur...
# 33     32     18  32_walking shoes_comfortable shoes_good walkin...
# 34     33     16  33_indiana jones_splash mountain_pirates carib...
# 35     34     15  34_gluten_gluten free_gluten free options_red ...
# 36     35     15  35_dreamed_disney land_dreamed going_childhood...
# 37     36     15  36_restrooms_bathrooms_restrooms clean rides_r...
# 38     37     15  37_monday_monday great_monday like_monday like...
# 39     38     15  38_kids_discount_park time visit_organized lig...
# 40     39     15  39_southern_disneyland_southern california_gre...
# 41     40     14  40_opened 1955_disneyland opened_going disneyl...
# 42     41     13  41_lunch princesses_bippity boppity_princesses...
# 43     42     13  42_60th anniversary_60th celebration_60th anni...
# 44     43     13  43_park save_kids adults_customer service_park...
# 45     44     12   44_family wonderful_magic disney_walt_day disney
# 46     45     11  45_love place_park world family_notch electric...
# 47     46     11  46_fast pass_certain rides_plus plenty shops_d...
# 48     47     11  47_hopper pass_fast passes_overpriced crowed s...
# 49     48     11  48_parades_nyc las vegas_parades impressed new...
# 50     49     10  49_miss lifetime_love construction happening_l...
# 51     50     10    50_indiana jones_indiana_thunder mountain_rides
# 52     51     10  51_rides_rides long queues_queues rides_matter...
# 53     52      9  52_day pass_day recommend_need day_nam girls feel
# 54     53      9  53_fast pass_lines_children_parents great waiting
# 55     54      9  54_monte cristo sandwich_pirates caribbean rid...
# 56     55      8  55_boyfriend_california adventure_boyfriend vi...
# 57     56      8  56_submarine_nemo submarine_submarine ride_nem...
#
#                                        Representation  \
# 0              [park, disneyland, rides, day, disney]
# 1       [disneyland, disney, rides, california, kids]
# 2               [place, family, year, magical, visit]
# 3   [fireworks, parade, parade fireworks, parades,...
# 4   [christmas, disneyland, disneyland christmas, ...
# 5        [expensive, disneyland, disney, money, love]
# 6   [birthday, 60th, 60th anniversary, disneyland,...
# 7   [annual pass, annual passes, times year, seaso...
# 8      [characters, rides, place, family, rides kids]
# 9   [halloween party, mickey halloween, mickey hal...
# 10  [staff, place, cleanliness, staff amazing, sta...
# 11  [california adventure, cars land, disneyland, ...
# 12  [wheelchair, disability, scooter, special need...
# 13  [christmas, christmas decorations, holiday dec...
# 14  [cast members, disneyland, cast members friend...
# 15  [park clean staff, disneyland park clean, staf...
# 16  [mansion, haunted mansion, nightmare christmas...
# 17  [halloween, halloween party, park halloween, d...
# 18  [pirates, pirates caribbean, pirates carribean...
# 19  [place earth, kidsbest place earth, earth kids...
# 20  [crowds, crowded, weather, crowds great, midwe...
# 21  [blue, food, blue bayou, california adventure,...
# 22   [rides, ages, theme park, family park, children]
# 23  [turkey leg, turkey legs, giant turkey leg, gi...
# 24      [rides, lines, visit, rides hour, hour early]
# 25  [star wars, jedi, star wars land, chewbacca da...
# 26  [cast members, cast members friendly, members ...
# 27  [mickey minnie, parade, world mickey, micky mi...
# 28     [park, day food, leap, clean staff, time park]
# 29  [fast pass, hopper pass, park hopper pass, fas...
# 30  [mickey, minnie mickey, mickey donald, kids, m...
# 31  [indiana jones ride, loved indiana jones, love...
# 32  [attractions closed, rides closed, ride closur...
# 33  [walking shoes, comfortable shoes, good walkin...
# 34  [indiana jones, splash mountain, pirates carib...
# 35  [gluten, gluten free, gluten free options, red...
# 36  [dreamed, disney land, dreamed going, childhoo...
# 37  [restrooms, bathrooms, restrooms clean rides, ...
# 38  [monday, monday great, monday like, monday lik...
# 39  [kids, discount, park time visit, organized li...
# 40  [southern, disneyland, southern california, gr...
# 41  [opened 1955, disneyland opened, going disneyl...
# 42  [lunch princesses, bippity boppity, princesses...
# 43  [60th anniversary, 60th celebration, 60th anni...
# 44  [park save, kids adults, customer service, par...
# 45  [family wonderful, magic disney, walt, day dis...
# 46  [love place, park world family, notch electric...
# 47  [fast pass, certain rides, plus plenty shops, ...
# 48  [hopper pass, fast passes, overpriced crowed s...
# 49  [parades, nyc las vegas, parades impressed new...
# 50  [miss lifetime, love construction happening, l...
# 51  [indiana jones, indiana, thunder mountain, rid...
# 52  [rides, rides long queues, queues rides, matte...
# 53  [day pass, day recommend, need day, nam girls ...
# 54  [fast pass, lines, children, parents great wai...
# 55  [monte cristo sandwich, pirates caribbean ride...
# 56  [boyfriend, california adventure, boyfriend vi...
# 57  [submarine, nemo submarine, submarine ride, ne...
#
#                                   Representative_Docs
# 0   [risked lives went highh season week Christmas...
# 1   [family returned day trip Southern California ...
# 2   [time family wait year hopefully took year old...
# 3   [Went park days Thoroughly enjoyed Staff helpf...
# 4   [Disneyland DCA times usually love early Decem...
# 5   [Disneyland ridiculous prices truly know creat...
# 6   [Happy 60th Birthday Disneyland!This 3rd visit...
# 7   [annual pass holders love Disneyland happiest ...
# 8   [Loved moment alot people lines bit crazy know...
# 9   [Went Disneyland Halloween Halloween favorite ...
# 10  [love great place staff friendly place makes f...
# 11  [Loved new expanded California Adventure Park ...
# 12  [Disneyland daughter Dance Studio performing b...
# 13  [busy time year Christmas decorations beautifu...
# 14  [Disneyland continues exceptional amusement pa...
# 15  [like Disneyland staff inside gate friendly he...
# 16  [holidays Disney Haunted Mansion transformed j...
# 17  [preface live Arizona annual pass resort biase...
# 18  [rides fantastic queues extremely long spring ...
# 19  [happiest place earth great age Forget age bal...
# 20  [original best Reasonable line ups summer vaca...
# 21  [family try trip Disney twice year parks offer...
# 22  [rides sights suitable senior happy adding cou...
# 23  [wandering Disneyland noticed tourists holding...
# 24  [visited Mon Fri great time Hit park opening a...
# 25  [arrived months ahead opening Star Wars Galaxy...
# 26  [lets like like Cast members great great time ...
# 27  [arrived busy queue sun strong damper moods pa...
# 28  [Yes park fun BUSY eat staying day food horren...
# 29  [blast Buying fast pass deal way Use app sign ...
# 30  [children perfect age enjoy character experien...
# 31  [Went 1995 years old brought memories rides go...
# 32  [love dland year major rides closed including ...
# 33  [Wear comfy shoes start walking routing come O...
# 34  [Dreams come true rides Splash mountain Space ...
# 35  [amusement park nut Disney fan said trade past...
# 36  [grew dreaming going Disneyland went time youn...
# 37  [Greatest place celebrate birthday definitely ...
# 38  [Usually Fridays busy Saturdays bit lighter fo...
# 39  [seen ones seen son hopefully visit people hot...
# 40  [lived Southern California life amazed easy Di...
# 41  [great time began opened left close Disneyland...
# 42  [place kid daughter wore Rapunzel dress day vi...
# 43  [60th anniversary amazing night parade magical...
# 44  [Great park lots variety way quick snack foods...
# 45  [magic began timeless classic dates fail disap...
# 46  [love place Lots things young old Great rides ...
# 47  [Loved setup thought little overpriced day spe...
# 48  [day Park Hopper pass Southern California City...
# 49  [alladin located hyperion theatre watch standa...
# 50  [Love think possibly day days perfect Parks le...
# 51  [Hyperspace Mountain favorite wrong Star Tours...
# 52  [awesome rides fun stay hydrated bring lots su...
# 53  [enjoyed day day pass spending hours decided r...
# 54  [Wow blast family wait return Lines bad fast p...
# 55  [ate way park time Corn Dogs Monte Cristo Ice ...
# 56  [fun experience boyfriend went best rides love...
# 57  [Great visit park spectacular rides getting ol...

# %%
model_neg.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1    412                    -1_park_disney_disneyland_rides
# 1       0    171                     0_disneyland_park_rides_disney
# 2       1     49                     1_disneyland_line_disney_rides
# 3       2     39                           2_park_people_staff_rude
# 4       3     33                          3_park_rides_disney_lines
# 5       4     24                  4_fast pass_rides_fastpass_disney
# 6       5     24                        5_rides_queues_minutes_park
# 7       6     19                  6_disney_park_hours_crowd control
# 8       7     15       7_long lines_stand line_gate line_line takes
# 9       8     13                        8_gate_passes_ticket_refund
# 10      9     10                        9_park_fast pass_walk_lines
# 11     10      9                         10_food_park_mickey_disney
# 12     11      8                      11_photos_park_fireworks_free
# 13     12      8  12_attractions closed_attractions_park_ride broke
#
#                                        Representation  \
# 0              [park, disney, disneyland, rides, day]
# 1            [disneyland, park, rides, disney, money]
# 2          [disneyland, line, disney, rides, minutes]
# 3               [park, people, staff, rude, security]
# 4           [park, rides, disney, lines, place earth]
# 5       [fast pass, rides, fastpass, disney, minutes]
# 6        [rides, queues, minutes, park, rides closed]
# 7         [disney, park, hours, crowd control, allow]
# 8   [long lines, stand line, gate line, line takes...
# 9    [gate, passes, ticket, refund, customer service]
# 10              [park, fast pass, walk, lines, rides]
# 11              [food, park, mickey, disney, seniors]
# 12            [photos, park, fireworks, free, mickey]
# 13  [attractions closed, attractions, park, ride b...
#
#                                   Representative_Docs
# 0   [Disney worth visit went hot day Wednesday mid...
# 1   [went disneyland Paris years ago funniest day ...
# 2   [thought long hard title written poor review l...
# 3   [spent weeks traveling honeymoon Disneyland pr...
# 4   [sad overcrowding greed basically ruined previ...
# 5   [Disney parks changed visited park revised Fas...
# 6   [went weekday early morning supposed peak day ...
# 7   [Went family day tickets Previously Tokyo Euro...
# 8   [security line area purchase tickets stand lin...
# 9   [family decided purchase Max Pass time inside ...
# 10  [normally visit season remember fact paid Twil...
# 11  [traveled Indiana Disney park smaller Florida ...
# 12  [looking forward visiting Disneyland let Long ...
# 13  [Disneyworld Florida times Eurodisney Paris Di...

# %%
topic_embedding_pos = model_pos.topic_embeddings_
similarity_matrix_pos = cosine_similarity(topic_embedding_pos)

topic_embedding_neg = model_neg.topic_embeddings_
similarity_matrix_neg = cosine_similarity(topic_embedding_neg)

similarity_pos_df = pd.DataFrame(similarity_matrix_pos)
similarity_neg_df = pd.DataFrame(similarity_matrix_neg)

# %%
topic_keywords_pos = model_pos.get_topics()
topic_keywords_neg = model_neg.get_topics()

# %%
similarity_threshold = 0.5

# %%
G_pos = nx.Graph()
for topic_id in range(len(topics_pos)):
    if topic_id in topic_keywords_pos:
        topic_keywords_pos_str = ', '.join([word for word, _ in topic_keywords_pos[topic_id][:2]])
        G_pos.add_node(topic_id, label = topic_keywords_pos_str)
        
# Add nodes
for topic_id in range(len(topics_pos)):
    if topic_id in topic_keywords_pos:
        topic_keywords_pos_str = ', '.join([word for word, _ in topic_keywords_pos[topic_id][:2]])
        G_pos.add_node(topic_id, label=topic_keywords_pos_str)

# Add edges
num_topics = len(similarity_matrix_pos)
for i in range(num_topics):
    for j in range(i + 1, num_topics):
        if similarity_matrix_pos[i, j] > similarity_threshold:
            if i in G_pos.nodes and j in G_pos.nodes:
                G_pos.add_edge(i, j)
    
pyvis_graph = net(height='800px', width='100%', notebook=True)
pyvis_graph.from_nx(G_pos)
pyvis_graph.barnes_hut()
pyvis_graph.show_buttons()
pyvis_graph.show('Positive_Sentiment_Theme_Network.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# Positive_Sentiment_Theme_Network.html
#         <iframe
#             width="100%"
#             height="800px"
#             src="Positive_Sentiment_Theme_Network.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
G_neg = nx.Graph()
for topic_id in range(len(topics_neg)):
    if topic_id in topic_keywords_neg:
        topic_keywords_neg_str = ', '.join([word for word, _ in topic_keywords_neg[topic_id][:2]])
        G_neg.add_node(topic_id, label = topic_keywords_neg_str)
        
# Add nodes
for topic_id in range(len(topics_neg)):
    if topic_id in topic_keywords_neg:
        topic_keywords_neg_str = ', '.join([word for word, _ in topic_keywords_neg[topic_id][:2]])
        G_neg.add_node(topic_id, label=topic_keywords_neg_str)

# Add edges
num_topics = len(similarity_matrix_neg)
for i in range(num_topics):
    for j in range(i + 1, num_topics):
        if similarity_matrix_neg[i, j] > similarity_threshold:
            if i in G_neg.nodes and j in G_neg.nodes:
                G_neg.add_edge(i, j)
    
pyvis_graph = net(height='800px', width='100%', notebook=True)
pyvis_graph.from_nx(G_neg)
pyvis_graph.barnes_hut()
pyvis_graph.show_buttons()
pyvis_graph.show('Negative_Sentiment_Theme_Network.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# Negative_Sentiment_Theme_Network.html
#         <iframe
#             width="100%"
#             height="800px"
#             src="Negative_Sentiment_Theme_Network.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
